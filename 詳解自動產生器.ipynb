# %% [markdown]
# <ul>
# 目前有的特殊前綴格式：
#     <li>*ph* = 片語</li>
#     <li>*tip* = 註解</li>
# </ul>
# <p>有些解釋後面接著"；"，那其以後的解釋(如果存在)便會直接接上</p>
# <p>如果沒有"；"，那其以後的解釋(如果存在)便會換到下一行</p>

# %%
wordsFilePath = 'C:\\Users\\User\\Desktop\\test.txt'
wordsFilePath = 'C:\\Users\\User\\OneDrive\\Documents\\文林心相關\\詳解\\詳解需求\\字典.txt'
partsOfSpeech = ['(n.)', '(a.)', '(adj.)', '(adv.)', '(v.)', '(vi.)', '(vt.)', '(prep.)', '(conj.)', '(pron.)', '(int.)', '(aux.)', '(pl.), ']

def cutTabMinimizeSpace(line):
    
    length = len(line)
    i = 0
    while True:
        if i >= length:
            break
        if line[i] == '\t':
            line = line[0:i] + line[i + 1:]
            length -= 1
        elif line[i] == ' ':
            if line[i + 1] != ' ':
                i += 1
            else:
                line = line[0:i] + line[i + 1:]
                length -= 1
        else:
            i += 1
    if line[0] == ' ': 
        return line[1:]
    else:
        return line
    
def cutNumber(line):
    
    while line[0].isnumeric():
        line = line[1:]
    return line[1:]

def cutHeadAndTailSpace(line):
    
    string = line
    while string[-1] == ' ':
        string = string[:len(string) - 1]
    while string[0] == ' ':
        string = string[1:]
    while string[0] == '\t':
        string = string[1:]
    while string[-1] == '\t':
        string = string[:len(string) - 1]
    while string[0] == '\u3000':
        string = string[1:]
    while string[-1] == '\u3000':
        string = string[:len(string) - 1]
    return string

def getDic():

    f = open(wordsFilePath, 'r', encoding = 'utf-16')



    lines = []
    dic = []
    group = []

    for line in f:
        tempStr = cutTabMinimizeSpace(line)[:-1]
        if len(tempStr) is not 0:
            lines.append(cutTabMinimizeSpace(line)[:-1])

    group.append(cutNumber(lines[0]))
    for line in lines[1:]:
        if line[0] >= '0' and line[0] <= '9':
            dic.append(group)
            group = []
            group.append(cutHeadAndTailSpace(cutNumber(line)))
        else:
            group.append(cutHeadAndTailSpace(line))
    dic.append(group)

    for groupNum in range(0, len(dic)):
        i = 0
        length = len(dic[groupNum])
        while True:
            if i + 1 >= length:
                break
            if dic[groupNum][i][-1] == '；':
                canUse = True
                for string in partsOfSpeech:
                    if dic[groupNum][i + 1].find(string) is not -1:
                        canUse = False
                        break
                if canUse:
                    dic[groupNum][i] += dic[groupNum][i + 1]
                    dic[groupNum] = dic[groupNum][0:i + 1] + dic[groupNum][i + 2:]
                    length -= 1
                else:
                    i += 1
            else:
                canUse = True
                for string in partsOfSpeech:
                    if dic[groupNum][i + 1].find(string) is not -1:
                        canUse = False
                        break
                if dic[groupNum][i + 1][0] != '=' and dic[groupNum][i + 1][0] != '↔' and dic[groupNum][i + 1][0] != '(':
                    canUse = False
                if canUse:
                    dic[groupNum][i] += dic[groupNum][i + 1]
                    dic[groupNum] = dic[groupNum][0:i + 1] + dic[groupNum][i + 2:]
                    length -= 1
                else:
                    i += 1

    '''
    for line in dic:
        for i in range(0, len(line) - 1):
            if len(line[i]) is not 0 and len(line[i]) is not 0:
                if '\u4e00' <= line[i + 1][0] and line[i + 1][0] <= '\u9fa5' and line[i][-1] != '；' and line[i][-1] != '，':
                    print(line)
                    break
    '''

    for group in dic:
        print(group)
    print('--------------------------------------------------------------------------------')
    print('--------------------------------------------------------------------------------')
    print('--------------------------------------------------------------------------------')

    return dic
    '''
    for group in dic:
        for line in group:
            found = -1
            for string in partsOfSpeech:
                found = line.find(string)
                if found != -1 and found != 0 and not (line[0].isalpha()):
                    print(line)
    '''
dic = getDic()
# Out:
# ['abbreviate (vt.)縮寫；縮短', '(vi.)使用縮寫詞', 'abbreviation (n.)[C]縮寫[+for/of]']
# ['abnormal (a.)不平常的；不正常的=out of ordinary', 'norm(n.)[C]標準；規範']
# ['aboriginal (a.)原來的；土著的=indigenous=native', 'aborigine (n.)[C]原住民']
# ['abound (vi.)豐富；富有', 'abundant (a.)豐足的[+in]=plentiful', 'abundance (n.)[U]豐足', 'redundant(a.)多餘的', '*ph*地方abound in/with N某地盛產某物= 地方be rich in N = N abound in地方']
# ['absence (n.)[U][C]缺席；不在[+from]；[U]缺乏[+of]', 'absent (a.)缺席的；不在場的', 'absent-minded(a.)心不在焉', 'absent-mindedness(n.)[U]心不在焉']
# ['abstract (a.)抽象的↔concrete=solid=tangible', '(n.)[C]摘要=summary=digest', 'abstraction (n.)[U][C]抽象觀念；心不在焉', 'abstracted (a.)分離的；心不在焉的']
# ['abuse (vt.)濫用；虐待；辱罵', '(n.)[U]濫用；虐待；辱罵；弊端', 'abusive (a.)被濫用的；口出惡言的']
# ['accelerate (vi.)加速↔decelerate', '(vt.)加快=hasten=hurry=quicken=speed up', 'acceleration (n.)[U]加速；促進；加速度↔deceleration']
# ['access (n.)[U]進入；使用[+to]；[U][C]通道；入口', '(vt.)(電腦的)存取', 'accessible (a.)易接近的[+to]=approachable']
# ['accessory (n.)[C]配件；附件', '(a.)附加的']
# ['accommodate (vi.)(vt.)適應[+to]=adapt=adjust', 'accommodation (n.)[U]住宿；住所；[C][U]和解', 'accommodating (a.)助人的；隨和的']
# ['accord (vi.)一致[+with]', '(vt.)授予；贈與=give', '(n.)[U]調和；一致；[C]協議；條約=pact=treaty=convention', 'according (a.)根據[+to]', 'accordingly (adv.)因此=therefore', 'accordance (n.)[U]一致；和諧；符合；授予']
# ['account (n.)[C]敘述[+of]；帳戶', '(vi.)說明；解釋[+for]', 'accountable (a.)有責任的；要負責的[+for sth./to sb.]', 'accountant (n.)[C]會計師', 'accounting (n.)[U]記帳；會計；會計學']
# ['accumulate (vt.)累積=gather=compile', '(vi.)堆積=build up', 'accumulation (n.)[C]累積']
# ['accuse (vt.)指責；控訴[+of]', 'accusation (n.)[C]指責；控訴']
# ['acquire (vt.)得到；取得；習得=get=gain', 'acquisition (n.)[C]獲得物；增添物；[U]獲得；取得', 'acquisitive (a.)貪得無厭的；可學得的']
# ['act (vt.)扮演[+as]；演出；代理[+for]', '(vi.)採取行動；舉動=behave；作用', '(n.)[C]行為；法案；(大寫)法令', 'action (n.)[C]行動；[U]實施', 'active (a.)活力充沛的=energetic=vigorous', 'activate (vt.)啟動', 'activity (n.)[C][U]活動', 'activist (n.)[C]激進主義份子；行動主義者', 'actor (n.)[C]男演員', 'actress (n.)[C]女演員']
# ['acute (a.)劇烈的=severe=intense；慢性的；急性的↔chronic；敏銳的=keen', 'SARS (Severe Acute Respiratory Syndrome) (n.)嚴重急性呼吸道症候群']
# ['adapt (vt.)改寫[+for/from]；使適應[+to]', '(vi.)適應[+to]=adjust[+to]', 'adaptation (n.)[C]改寫本；[U]適應[+to]', 'adaptable (a.)適應性強的']
# ['addict (vt.)沈迷；上癮[+to]', '(n.)[C]入迷的人；成癮的人', 'addiction (n.)[U][C]上癮[+to]', 'addictive (a.)令人上癮的']
# ['administer (vt.)管理=manage=govern', 'administrate (vt.)管理；支配', 'administrator (n.)[C]管理人；行政官員', 'administration (n.)[U]管理；[C]行政部門', 'administrative (a.)管理上的；行政的']
# ['advocate (n.)[C]提倡者；擁護者[+of]', '(vt.)擁護；提倡；主張']
# ['affect (vt.)影響=influence；使感染(病)=attack；感動=move；假裝=pretend', 'affecting (a.)令人感動的', 'affection (n.)[U]影響；[C]感染；屬性；[U][C]愛慕；鍾愛', 'affectionate (a.)充滿深情的；溫柔真切的', 'affectation (n.)[U][C]做作；裝模作樣']
# ['affirm (vt.)斷言；證實[+as]；堅稱', '(vi.)斷言；聲明=declare', 'affirmative (a.)肯定的', '(n.)[C]肯定詞', 'affirmation (n.)[C][U]斷言；肯定；證實；批准']
# ['aggress (vi.)侵略；挑釁；攻擊', 'aggressive (a.)積極的；侵略性的；具攻擊性的', 'aggression (n.)[U]侵略+against；[C]侵略行動；侵犯行為[+on/upon/against]']
# ['alcohol (n.)[U]酒；酒精', 'alcoholic (a.)含酒精的', '(n.)[C]酒鬼']
# ['alien (a.)不同的；外國的；性質不同的', '(n.)[C]外來的人；外星人', 'alienate (vt.)疏離[+from+sb./sth.]=isolate']
# ['allocate (vt.)分配[+ sth. for sth.]', 'allocation (n.)[U][C]分配；配額']
# ['ally (vt.)使聯繫；使結盟[+with/to]', '(vi.)結盟；聯合[+with/against]', '(n.)[C]聯繫；同盟國', 'alliance (n.)[C]聯盟；同盟；共通點']
# ['alongside (adv.)在旁邊；沿著；並排地', '(prep.)沿著…的邊；與…並排']
# ['alter (vt.)改變=change', '(vi.)改變；變樣', 'alternate (a.)輪流的；交替的；間隔的', '(n.)[C][美]代理人；代替者', '(vi.)交替；輪流[+with/between]', '(vt.)使交替；使輪流[+with]', 'alternative (a.)二者擇一的；選擇的；替代的', '(n.)[U]選擇的自由、餘地；[C]代替人；代用品[+to]=substitute[+for]', 'alteration (n.)[U][C]改變；變更；修改']
# ['ambiguous (a.)模棱兩可的=vague↔obvious', 'ambiguity (n.)[U]模稜兩可=vagueness；']
# ['ambulance (n.)[C]救護車；戰地醫院']
# ['ambush (n.)[C][U]埋伏', '(vt.)(vi.)埋伏下來；伏擊']
# ['amiable (a.)和藹可親的；友善的=friendly=agreeable']
# ['ample (a.)足夠的；廣大的=sufficient', 'amply (adv.)充足地；廣闊地；詳細地', 'amplify (vt.)擴大；擴展；詳述', '(vi.)發揮；詳述[+on]', 'amplification (n.)[U]擴大；詳述']
# ['analects (n.)文選；語錄']
# ['analogy (n.)[C][U]類似；近似；類比=comparison', 'analogous (a.)類似的；可比擬的[+to/with]']
# ['analyze (vt.)分析；分解=examine', 'analysis (n.)[C]分析；分解[+of]', 'analyst (n.)[C]分析家；分解者', 'analytic (a.)分析的', 'analytical (a.)分析的=analytic']
# ['anecdote (n.)[C]軼事；趣聞']
# ['animation (n.)[U]生機；活潑；[C]卡通片；動畫', 'animate (vt.)使活潑；激勵；給予生命', '(a.)有生命的；有活力的↔inanimate', 'animator (n.)[C]卡通片繪製者；賦予活力者']
# ['annoy (vt.)使煩惱；打攪=irritate', '(vi.)令人生氣、不快', 'annoyance (n.)[U]煩惱；惱怒；打擾；[C]使人煩惱的人或事=nuisance=disturbance']
# ['anonym (n.)[C]假名；匿名者；無名氏', 'anonymous (a.)匿名的；不具名的', 'anonymity (n.)[U]匿名；無名']
# ['Antarctica (n.)南極洲']
# ['antenna (n.)[C]觸角；觸鬚；天線', 'antibiotic (a.)抗菌的；有害生命的', '(n.)抗生素', 'antibody (n.)[C]抗體', 'antinuclear (a.)反核子的', 'antisocial (a.)反社會的；不善社交的', 'antitrust (a.)反托拉斯的(反社會壟斷的)']
# ['anticipate (vt.)預期；期待=expect=predict', 'anticipation (n.)[U][C]預期；期待']
# ['antonym (n.)[C]反義字↔synonym']
# ['apply (vt.)塗抹；應用[+to]', '(vi.)申請；請求[+for]', 'appliance (n.)[C]器具；裝置；運用', 'application (n.)[U][C]塗抹；應用；申請', 'applicant (n.)[C]申請者；應徵者[+for]', 'applicable (a.)可應用的；合適的[+to]']
# ['apprentice (n.)[C]學徒', '(vt.)(vi.)當學徒']
# ['approximate (vt.)大致相當[+to]=be close to', '(vi.)接近[+to]', '(a.)近似的；大約的', 'approximately (adv.)大約地', 'approximation (n.)接近；概算；近似值']
# ['aptitude (n.)[C]天賦；才能[+for]']
# ['Arctic (n.)北極地帶；北極圈']
# ['arrogant (a.)自大的；驕傲的[+toward]=proud=cavalier', 'arrogance (n.)[U]自大；傲慢']
# ['artery (n.)[C]動脈；主要幹道', 'vein/capillary(n.)[C]靜脈/微血管']
# ['articulate (a.)發音清晰的；口才好的', '(vt.)清楚發音；表達', 'articulation (n.)[U]發音；咬字']
# ['artifact (n.)[C]工藝品；人工製品', 'artifice (n.)[C]詭計；[U]狡詐；欺騙', 'artificial (a.)人工的；虛偽的；做作的=man-made=synthetic↔natural']
# ['assassin (n.)[C]刺客；殺手', 'assassinate (vt.)暗殺；行刺', 'assassination (n.)[C][U]暗殺行動；行刺']
# ['assert (vt.)主張；聲明；斷言=claim=affirm', 'assertive (a.)斷言的；獨斷的；肯定的', 'assertion (n.)[U]主張；堅持；[C]聲明；斷言']
# ['assess (vt.)評估；評定；估價=estimate', 'assessment (n.)[C]評估；估定金額；[U]估價']
# ['assume (vt.)假定；假裝=think=suppose；採取；承擔=shoulder=take on', 'assumption (n.)[U][C]假定；設想；承擔']
# ['asthma (n.)[U]氣喘病']
# ['asylum (n.)[U]避難；[C]避難所；收容所=refuge']
# ['attain (vt.)獲得=gain；到達=achieve', '(vi.)達到；獲得[+to]', 'attainment (n.)[U]獲得；成就=achievement=accomplishment=fulfillment']
# ['attend (vt.)參加=be present at；照料=look after', '(vi.)注意[+to]=pay attention to', 'attentive (a.)注意的；專心的；殷勤的[+to]', 'attention (n.)[U]注意；專心[+to]=heed', 'attendant (n.)[C]出席者；隨從；服務員', '(a.)伴隨的；出席的[+on]', 'attendance (n.)[U]參加；出席；隨從人員']
# ['attic (n.)[C]閣樓']
# ['auction (n.)[U]拍賣；[C]拍賣會', '(vt.)拍賣[+ sth. off]']
# ['authentic (a.)可信的=trusty=trustworthy；真實的=genuine；非假冒的']
# ['authority (n.)[U]權威；當局[+over]=control', 'authorize (vt.)授權；批准[+ sb. to V]=empower', 'authorization (n.)[U]授權']
# ['automatic (a.)自動的', 'automobile (n.)[C]汽車', 'autobiography (n.)[C]自傳', 'autograph (n.)名人的簽名']
# ['autonomy (n.)[U]自治[+from]', 'autonomous (a.)自治的']
# ['aviation (n.)[U]航空術；航空學']
# ['awe (n.)[U]敬畏；害怕', '(vt.)使敬畏；使害怕', 'awful (a.)驚人的；可怕的=unpleasant', '(adv.)十分地', 'awesome (a.)令人感到敬畏的；妙極了=extremely good']
# ['barometer (n.)[C]氣壓計']
# ['beckon (vt.)向…示意；召喚；吸引；引誘', '(vi.)示意；召喚[+to]；吸引；引誘', '(n.)[C](表示召喚的)點頭；手勢']
# ['besiege (vt.)圍攻；圍繞；困擾', 'siege(n.)[U][C]包圍；圍攻']
# ['betray (vt.)出賣；背叛；洩密=sell out；暴露；顯示=show', 'betrayal (n.)[C][U]背叛；背信；密告']
# ['beverage (n.)[C]飲料=drink']
# ['bias (n.)[C]偏見[+against]=prejudice；', '(a.)斜的；斜紋的', '(adv.)傾斜地；對角地', '(vt.)使有偏心；使存偏見']
# ['binoculars (n.)[C]雙筒望遠鏡；雙目顯微鏡']
# ['biochemistry (n.)生化科學']
# ['biology (n.)[U]生物學；生態學', 'biological (a.)生物的；生物學的']
# ['bizarre (a.)古怪的；不尋常的=weird=odd']
# ['bleak (a.)荒涼的；嚴寒的；嚴峻的']
# ['blunder (n.)[C]錯誤；大錯=boner', '(vi.)犯大錯；失策；疏忽', '(vt.)做錯；辦錯事情']
# ['blunt (a.)鈍的；粗魯的；遲鈍的', '(vt.)(vi.)弄鈍；使減弱']
# ['bomb (n.)[C]炸彈', '(vt.)(vi.)轟炸；轟擊；投彈', 'bombard (vt.)砲轟；連續攻擊；質問[+with]', 'bombshell (n.)炸彈；突發事件']
# ['bond (n.)[C]羈絆；[C]契約；監禁', '(vt.)以…抵押；將(磚石)砌合', '(vi.)黏合；結合', 'bondage (n.)[U]奴役；囚禁；奴隸身分']
# ['boost (n.)抬舉；推動；提高；增強', '(vt.)舉；抬；提高；增加']
# ['bout (n.)[C]一回、一次；競爭[+of]；(疾病的)發作[+of]']
# ['boycott (vt.)聯合抵制(下對上)；拒絕參加；杯葛', '(n.)[C]抵制(下對上)；拒絕參加；杯葛']
# ['breakdown (n.)[C]故障；崩潰；破裂；衰竭']
# ['breakthrough (n.)[C]突破性的進展；突破點']
# ['breakup (n.)[C]中止；中斷；分裂；崩潰']
# ['brew (vt.)釀；沖泡；醞釀；用…釀酒', '(vi.)釀酒；醞釀著；即將發生', '(n.)[C]一泡(茶、酒、咖啡)', 'brewage (n.)釀製的飲料']
# ['brink (n.)邊緣']
# ['brisk (a.)敏捷的；輕快的；活躍的', '(vt.)使活潑；使活躍', '(vi.)變的輕快；活躍起來']
# ['brochure (n.)[C]小冊子=pamphlet=booklet']
# ['brute (n.)[C]野獸；畜生；殘暴的人', '(a.)畜生的；慘忍的；無理的', 'brutal (a.)殘忍的；獸性的；冷酷的']
# ['buckle (n.)[C]扣子；帶扣', '(vt.)扣住；使連接； 使全力以赴', '(vi.)扣住；扣緊；連接']
# ['bulky (a.)體積大的；龐大的']
# ['bureau (n.)[C]政府機關部門', 'bureaucracy (n.)[C]官僚制度；[U]繁文縟節']
# ['bury (vt.)埋；掩蓋；使專心於；使沉浸', 'burial (n.)[U][C]埋葬；葬禮']
# ['caffeine (n.)咖啡因']
# ['calcium (n.)[U]鈣']
# ['canvas (n.)[U]帆布；[C][U]油畫(布)']
# ['capable (a.)有能力的；能幹的[+of]', 'capability (n.)[C][U]能力=ability；才幹', 'capacity (n.)[U]容量；[C]資格；職位；']
# ['capsule (n.)[C]膠囊；座艙；被膜']
# ['caption (n.)字幕；標題=heading=title']
# ['capture (vt.)捕獲；逮捕；俘虜↔release', '(n.)[U]捕獲；逮捕；俘虜=prisoner；記錄；留存；[C]俘虜；戰利品', 'captive (n.)[C]俘虜；囚徒', '(a.)被俘的=imprisoned', 'captivity (n.)[U]囚禁；被俘']
# ['carbon (n.)[U]碳', 'carbohydrate (n.)[C][U]碳水化合物；醣']
# ['caress (vt.)愛撫=stroke；親吻；擁抱；寵愛', '(n.)[C]愛撫；親吻；擁抱']
# ['carol (n.)[C]頌歌=hymn；讚美詩=anthem']
# ['cash (n.)[U]現金；現款', '(vt.)把…兌現', 'cashier (n.)[C]出納員']
# ['casual (a.)隨意的；漫不經心的；非正式的', 'casualty (n.)[C]意外事故；傷亡人數=toll']
# ['catastrophe (n.)[C]大災難=disaster=calamity', 'catastrophic (a.)災難的；悲慘的=miserable=pathetic']
# ['cater (vi.)迎合[+for/to]=satisfy；承辦筵席[+for]', '(vt.)為…提供飲食']
# ['cavalry (n.)[C]騎兵；騎兵部隊']
# ['cave (n.)[C]洞穴=hole', '(vt.)挖洞；使坍塌', '(vi.)塌落；倒塌[+in]', 'cavity (n.)[C]洞穴；空腔']
# ['cemetery (n.)[C]墓地=grave=tomb；公墓']
# ['certain (a.)確信的；無疑的', 'certainly (adv.)當然；確實=for certain=for sure']
# ['certificate (n.)[C]證書；執照', 'certification (n.)證明；保證', 'certify (vt.)證明=confirm；證實；擔保；保證=guarantee']
# ['champagne (n.)[U]香檳']
# ['chaos (n.)[U]混亂=confusion↔order', 'chaotic (a.)混亂的；雜亂無章的；無秩序的']
# ['character (n.)[C][U]人物；人格；[C]字體', 'characterize (vt.)具有...的特徵；以…為特徵', 'characteristic (a.)特別的；有特性的；典型的', '(n.)[C]特性；特徵']
# ['charcoal (n.)[U]炭；木炭']
# ['chariot (n.)[C]馬車']
# ['charity (n.)[U]慈愛；寬容；[C]施捨物；慈善團體', 'charitable (a.)慈悲的=sympathetic[+to]；仁善的；體諒的']
# ['cholesterol (n.)膽固醇']
# ['chronic (a.)慢性的=lingering；積習難改的=habitual；長期的↔temporary']
# ['chuckle (n.)[C]竊笑=giggle；輕笑聲']
# ['chunk (n.)[C]大塊；厚片=lump']
# ['civil (a.)公民的；國內的', 'civilize (vt.)使教化=cultivate；使開化', '(vi.)變的文明=refine', 'civilization (n.)[U][C]文明；教化', 'civilian (n.)[C]平民；百姓', 'citizen (n.)[C]公民；市民', 'civic (a.)城市的；市民的；公民的']
# ['clamp (n.)[C]夾鉗；夾子', '(vt.)鉗緊=clasp；夾住=fasten=brace']
# ['clarity (n.)[U]明確↔obscurity；清澈=transparency']
# ['cleanse (vt.)使清潔=clean↔dirty；清洗']
# ['clearance (n.)[U]清除；清空；出空']
# ['clench (n.)[C]抓緊；握緊=grasp↔loose；咬緊']
# ['clinic (n.)[C]診所；門診', 'clinical (a.)診所的；臨床的；客觀的=objective↔emotional']
# ['clone (n.)無性生殖；仿製品=copy']
# ['close (vt.)(vi.)關閉；結束；蓋上', '(a.)接近的；親密的[+to]', 'closed (a.)關閉的', 'closely (adv.)靠近地；緊密地；仔細地', 'closure (n.)關閉=shutting↔opening；打烊；中止']
# ['coffin (n.)[C]棺材']
# ['coherent (a.)一致的=accordant=consonant；協調的=congruous=congenial']
# ['coincide (vi.)同時發生[+with]；相符[+with]=correspond↔disagree', 'coincidence (n.)[U][C]巧合']
# ['collect (vt.)(vi.)收集；集中；鎮定；堆積', 'collection (n.)[U][C]收集；[C]收藏品', 'collector (n.)[C]收藏者', 'collective (a.)集合的=united↔separate；共同的']
# ['collide (vi.)碰撞[+with]=crash；衝突；抵觸=conflict with=clash with', 'collision (n.)[U][C]碰撞；衝突=conflict']
# ['colloquial (a.)口語的=informal=oral=verbal；會話的=conversational']
# ['column (n.)[C]圓柱；專欄', 'columnist (n.)專欄作家']
# ['commemorate (vt.)慶祝=celebrate；紀念=memorialize']
# ['commence (vt.)(vi.)開始=begin↔finish；著手於']
# ['comment (vt.)(vi.)解釋；評論；發表意見', '(n.)[C][U]註解；評論', 'commentary (n.)[C]評論=comment', 'commentator (n.)[C]時事評論者=critic；評註者']
# ['commit (vt.)犯罪；承擔義務；提交給', 'commitment (n.)[U][C]承諾=promise；獻身=devotion']
# ['communicate (vi.)通訊；交流；交際', '(vt.)傳達；傳播；傳遞', 'communication (n.)[U]傳達；交流；[C]訊息；情報', 'communicative (a.)愛交際的；愛說話的=talkative↔quiet']
# ['company (n.)[C]公司；同伴；[U]陪伴', 'companion (n.)[C]朋友；夥伴', 'companionship (n.)[U]交情；作伴']
# ['compare (vt.)比較；對照；比喻', '(vi.)相比；匹敵', '(n.)[U]比較', 'comparison (n.)[C][U]比較', 'comparable (a.)可相比的[+with]=as good', 'comparative (a.)比較的；相對的=relative']
# ['compatible (a.)適合的[+with]↔incompatible；相容的']
# ['compensate (vt.)(vi.)補償=make up；賠償', 'compensation (n.)[U]補償(金)；報酬']
# ['competent (a.)勝任的=capable；有能力的', 'competence (n.)[U]能力=ability；稱職']
# ['compile (vt.)編彙；收集(資料)']
# ['complement (n.)[C]補充物=supplement；補給']
# ['complex (a.)複雜的', '(n.)[C]複合物；↔合體；情結', 'complexity (n.)[U]複雜↔simplicity', 'complexion (n.)[C]膚色；[U]性質、情況']
# ['complicate (vt.)使複雜化；使難應對', 'complicated (a.)複雜的；難懂的', 'complication (n.)[U][C]複雜；[C]併發症；困難；障礙']
# ['component (n.)[C]成份；組成要素=element']
# ['comprehend (vt.)理解；包含', 'comprehensive (a.)廣泛的；全面性的=thorough', 'comprehension (n.)[U]理解力；包含力']
# ['comprise (vt.)包含=consist of；包括；組成']
# ['concede (vt.)承認(失敗)=admit↔deny；讓予', '(vi.)讓步[+to]=give in↔keep；承認失敗', 'concession (n.)[C]讓步(行為)；讓予物；租界']
# ['conceit (n.)[U]自負；自大', 'conceited (a.)自負的=arrogant↔humble；驕傲的']
# ['conceive (vi.)構想；認為；懷孕', '(vt.)構想出；想像；設想', 'conception (n.)[U][C]觀念=conception；想法；懷孕', 'concept (n.)[C]觀念；概念；思想', '*tip*請參閱Around Words 第6組/第53組']
# ['concise (a.)簡潔的=brief↔wordy；簡明的']
# ['condense (vt.)濃縮=concentrate；使凝結；聚集', '(vi.)濃縮；凝結；冷凝', 'condensation (n.)[U][C]濃縮；摘要；凝結']
# ['confer (vt.)授予(學位)=bestow↔withdraw；給予', '(vi.)協商；商談=discuss', 'conference (n.)[C][U]會議；討論']
# ['confidence (n.)[U]自信；信任', 'confident (a.)有信心的；確信的', 'confidential (a.)機密的=private↔open']
# ['conform (vi.)遵從=follow↔disobey；適應；符合=correspond to↔differ from', '(vt.)使遵照；使符合', 'conformity (n.)[U]遵從；符合；一致']
# ['confront (vt.)面對；遭遇；正視；對抗', 'confrontation (n.)[C][U]面臨；對質；對抗']
# ['congress (n.)[C][U]會議', 'congress (n.)美國國會', 'congressperson (n.)美國國會(眾議院)議員', 'congresswoman (n.)美國國會眾議院女議員', 'congressman (n.)美國國會眾議院男議員']
# ['conquer (vt.)攻克；征服', '(vi.)得勝；勝利', 'conqueror (n.)[C]征服者', 'conquest (n.)[U]克服=overcoming；征服=defeat；']
# ['conscience (n.)[C][U]良心；道德', 'conscientious (a.)憑良心的；認真負責的=responsible↔irresponsible']
# ['consensus (n.)[C][U]共識=general agreement↔disagreement；一致']
# ['conserve (vt.)保育；節省', 'conservative (a.)保守的；傳統的', '(n.)[C]保守者；守舊者', 'conservation (n.)[U]保育=preservation↔waste；節約']
# ['console (vt.)安撫；慰問=comfort↔distress', 'consolation (n.)[U]安慰；慰藉；[C]慰藉(人、事)']
# ['conspire (vi.)密謀；策劃', 'conspiracy (n.)[C][U]陰謀；共謀=plot']
# ['constituent (a.)組成的', '(n.)[U]成分=element']
# ['consult (vi.)商量；諮詢；當顧問', '(vt.)與…商量；請教；查閱(字典、參考書)', 'consultant (n.)[C]顧問', 'consultation (n.)[U][C]商量=conference；諮詢']
# ['consume (vt.)消耗；耗盡；燒毀', 'consumption (n.)[U]消費↔production；消耗=exhaustion', 'consumer (n.)消費者=customer']
# ['contemplate (vt.)(vi.)沉思=ponder on；考慮=consider', 'contemplation (n.)[U]深思熟慮']
# ['contest (n.)[C]競爭；比賽', '(vt.)競爭；爭辯', '(vi.)與…競賽', 'contestant (n.)[C]參賽者；競爭者=competitor↔teammate']
# ['contract (vt.)訂立；承包；使收縮；沾染；患病', '(vi.)訂約；承包；縮小', '(n.)[C]契約；合同', 'contractor (n.)[C]立約者；承包商', 'contraction (n.)[C][U]收縮；沾染']
# ['contradict (vi.)發生矛盾；否認；反駁', '(vt.)與…抵觸；與…矛盾=conflict with↔correspond with；否認；反駁=deny↔support', 'contradiction (n.)[C][U]矛盾；[C]矛盾說詞', 'contradictory (a.)矛盾的；好反駁的']
# ['controversy (n.)[U][C]爭論=dispute↔agreement；爭議', 'controversial (a.)具爭議性的']
# ['convict (vt.)判決…有罪；證明…有罪', '(n.)囚犯', 'conviction (n.)[U][C]定罪=condemnation']
# ['coordinate (vt.)(vi.)協調=organize；一致；使調和', '(a.)協調的；同等的', 'coordination (n.)協調；同等；對等']
# ['cordial (a.)熱忱的=zealous；友好的=friendly↔hostile']
# ['core (n.)核心=heart']
# ['corporate (a.)法人的；公司團體的', 'corporation (n.)[C]財團法人；股份公司']
# ['corps (n.)[C]部隊；團體=team']
# ['corpse (n.)[C]屍體=body']
# ['correspond (vi.)符合；通信', 'correspondence (n.)[U][C]一致；通信；信件', 'correspondent (n.)[C]通信員；特派員=reporter', 'corresponding (a.)相對應的']
# ['corrupt (a.)腐敗的；貪污的', '(vi.)腐敗；賄賂；墮落', '(vt.)使腐敗；使墮落', 'corruption (n.)[U]貪污=fraud；腐敗=morality']
# ['cosmetic (a.)化妝的', 'cosmetics (n.)化妝品', 'cosmetician (n.)化妝師']
# ['cosmos (n.)宇宙', 'cosmic (a.)宇宙的；廣大的；無限的', 'cosmopolitan (a.)世界性的=international；國際性的']
# ['counterpart (n.)[C]相像之人事物=equivalent；副本']
# ['cover (vt.)覆蓋；掩飾[+up]；包括；採訪；報導', '(n.)[C]掩蓋物；封面', 'coverage (n.)覆蓋範圍；新聞報導=reporting']
# ['covet (vt.)(vi.)貪圖；渴望=long for', 'covetous (a.)貪圖的；渴望的[+of]']
# ['cramp (n.)[C]夾鉗；鐵鉗', '(vt.)用鉗夾；限制=restrict']
# ['credit (n.)[U]信譽；信用；賒帳；功勞；[C]學分', '(vt.)相信；把...歸於；把...記入貸方', 'credible (a.)可信的=convincing', 'credibility (n.)[U]可信度；信用', 'incredible (a.)難以置信的', 'credulous (a.)輕易相信的↔incredulous', 'creditable (a.)值得稱讚的[+to]']
# ['criterion (n.)[C]衡量標準=standard']
# ['crook (vt.)使彎曲=bend', '(vi.)彎曲', '(n.)[C]彎曲=bend；彎曲', 'crooked (a.)彎曲的；欺詐的']
# ['crucial (a.)決定性的；重要的=critical']
# ['crude (a.)粗糙的；未加工的=raw；粗俗的=vulgar↔elegant']
# ['cruise (vi.)巡航；巡行=sail', '(vt.)巡航於；巡行於', '(n.)[C]巡航；航遊=voyage', 'cruiser (n.)[C]巡航艦；遊輪']
# ['crumb (n.)[C]麵包屑；碎屑', '(vt.)捏碎；弄碎']
# ['crumble (vt.)粉碎；弄碎=crush', '(vi.)破碎；碎裂；崩塌=fall']
# ['crust (n.)[C][U]麵包皮；派餅皮；硬皮；地殼']
# ['cultivate (vt.)栽培；培育；陶冶', 'cultivation (n.)[U]耕種；栽培；教養']
# ['cumulative (a.)累積的=collective']
# ['custom (n.)[C][U]習俗；[C]習慣', 'customs (n.)關稅', 'customary (a.)合乎習俗的=usual↔unusual']
# ['daffodil (n.)[C]黃水仙花；[U]淡黃色', '(a.)淡黃色的']
# ['dandruff (n.)[U]頭皮屑']
# ['daybreak (n.)[U]黎明；破曉=dawn']
# ['dead (a.)死的；無效的；麻木的；肯定無疑的', '(adv.)完全地；直接地', '(n.)(單複數同形)死者；[the S]最寂靜之時', 'deadly (a.)致命的=fatal=mortal=lethal；毒性的；不共戴天的；非常的；令人厭煩的', '(adv.)死一般地；極度地=extremely=dreadfully', 'death (n.)[C][U]死亡；[C]致死原因；[U]毀滅；(大寫)死神', 'deadline (n.)[C]最後限期；截稿時間']
# ['decent (a.)體面的；合理的=reasonable；親切的；端正的=respectable', 'decency (n.)[U]合宜；寬容；行為準則']
# ['decide (vt.)決定；使下決心；判決', '(vi.)決定[+against/for/on]', 'decided (a.)明確的；決定了的；果斷的', 'decisive (a.)決定性的=crucial；確定的；果斷的', 'decision (n.)[C][U]判斷；決定；[U]決心']
# ['decline (vi.)下降；減少；衰退；謝絕；傾斜', '(vt.)婉拒；謝絕', '(n.)下降；減少；衰退；傾斜']
# ['dedicate (vt.)以…奉獻=devote=commit；題獻；為(建築物等)舉行落成典禮', 'dedicated (a.)專注的；獻身的=devoted', 'dedication (n.)[C]揭幕儀式；題辭；[U]奉獻[+to]=devotion=commitment']
# ['deem (vt.)(無進行式)認為；以為；視作=consider', '(vi.)(無進行式)持…看法；作…評價']
# ['defect (n.)[C]缺點=fault=flaw；缺陷；不足之處', '(vi.)變節；脫離；背叛投敵[+to/from]', 'defection (n.)背叛；脫黨；不履行義務', 'treason(n.)[U]叛國罪']
# ['deficient (a.)有缺陷的；有缺點的；缺乏的', 'deficiency (n.)[U][C]缺乏；缺陷=flaw=defect；', 'deficit (n.)[C]不足額；赤字']
# ['degrade (vt.)降低…地位(質量、價值等)=devalue；使丟臉；使降級', 'degradation (n.)[U]下降；降低；降級；墮落']
# ['deliberate (a.)深思熟慮的；謹慎的；蓄意的', '(vi.)(vt.)仔細考慮；商議[+about/on/upon]', 'deliberately (adv.)從容不迫地；謹慎地；蓄意地=intentionally=by intention=on purpose=purposefully', 'deliberation (n.)[U]深思；研究；慎重；商議']
# ['delinquent (a.)怠忽職守的；到期未付的；犯法的', '(n.)[C]青少年犯；違法者；有過失者', 'delinquency (n.)懈怠；違法行為；少年犯罪']
# ['denounce (vt.)指責；譴責=condemn=censure；廢除；終止=abolish']
# ['dense (a.)稠密的(煙、霧等)；濃厚的；愚鈍的', 'densely (adv.)濃密地；稠密地；密集地↔sparsely', 'density (n.)[U][C]密集(度)；[U]密度；愚鈍']
# ['dental (a.)牙齒的；牙科的；齒音的', '(n.)[C]齒音', 'dentist (n.)[C]牙科醫生']
# ['depict (vt.)描畫；雕出；描述=describe=portray', 'depiction (n.)[U][C]描述；敘述']
# ['deprive (vt.)剝奪[+of]；免去...的職務', 'deprivation (n.)剝奪；免職；損失']
# ['deputy (n.)[C]代表；代理人=substitute；副手', '(a.)代理的；副的']
# ['derive (vt.)取得=obtain；衍生出=originate；導出[+from]', '(vi.)起源；衍生；導出[+from]']
# ['descent (n.)[U][C]下降；[U]世系；遺傳；衰落；繼承；[C]入侵', 'descend (vt.)下降；下傾=slope=incline；來自；突然來[+on]；墮落', '(vi.)走下；沿…向下', 'descendant (n.)[C]子孫；後裔=offspring(單複同形)', '(a.)下降的；降落的；祖傳的；世襲的']
# ['designate (vt.)標出；委任；指派', '(a.)選定的']
# ['destine (vt.)命定；預定；指定(作某種用處)', 'destined (a.)命中注定的(場所)；預定的', 'destiny (n.)[C]命運；[U]神意；(大寫)命運之神']
# ['detach (vt.)分開[+from]↔attach；拆卸；派遣', 'detachment (n.)[U]分離；派遣；不偏不倚；超脫']
# ['detain (vt.)使耽擱=delay；拘留=confine']
# ['deter (vt.)威懾住；嚇住；使斷念[+from]']
# ['detergent (a.)去垢的；使潔淨的', '(n.)[C][U]洗潔劑；洗衣粉']
# ['deteriorate (vi.)惡化；質量(或價值)下降；退化；墮落=worsen=decline↔improve', '(vt.)使惡化；使下降；使退化；使墮落', 'deterioration (n.)惡化；退化；[U]墮落']
# ['devalue (vt.)使…貶值=degrade=devaluate↔elevate；減少…的重要性']
# ['diabetes (n.)糖尿病']
# ['diagnose (vt.)診斷', 'diagnosis (n.)[C][U]診斷；診斷結果；診斷書', 'diagnostic (a.)診斷的；特徵的', '(n.)診斷結論']
# ['diagram (n.)[C]圖表=chart；圖解=illustration；(曲)線圖；示圖', '(vt.)用圖解法表示；圖示']
# ['diameter (n.)[C]直徑；倍(透鏡等的放大單位)']
# ['dictate (vt.)(vi.)口述；命令=order=command；規定；支配', '(n.)[C]命令；支配', 'dictation (n.)[U]口述；命令；口授(或聽寫)的文字', 'dictator (n.)[C]獨裁者=absolute ruler；']
# ['differentiate (vt.)構成…間的差別[+from]=distinguish', '(vi.)區別；區別對待[+between]', 'differential (a.)差別的；依差別而定的；與眾不同的', '(n.)[C](可相比事物間的)差別；[U]微分']
# ['dilemma (n.)[C]困境；進退兩難']
# ['dimension (n.)(長、寬、厚、高等的)尺寸=size；範圍；[C]方面=aspect', '(vt.)在…上標尺寸；按規格尺寸切割']
# ['diminish (vt.)減少；削弱…權勢=reduce=lessen；降低…聲譽', '(vi.)變小；縮小']
# ['diplomacy (n.)[U]外交；交際手腕；策略=tact；圓滑', 'diplomat (n.)[C]外交官；有手腕的人；處事圓滑者', 'diplomatic (a.)外交(人員)的；有外交手腕的=tactful']
# ['direct (vt.)將(注意力,談話等)指向；針對；主持；指示；導演；指揮(演奏)；指點', '(vi.)指導；指揮', '(a.)筆直的；直接的；嫡系的', '(adv.)筆直地；直接地；直達地', 'directory (n.)[C]電話簿；工商名錄；使用手冊；董事會=board', '(a.)指導的；諮詢的', 'director (n.)[C]局長；主任；董事；導演；指揮=conductor；控制器=controller', 'direction (n.)[C][U]方向；趨勢；領域；指導；管理', 'directly (adv.)直接地；坦率地；馬上=immediately=instantly', '(conj.)一…就=as soon as']
# ['disable (vt.)使無能力↔enable；使傷殘=handicap', 'disability (n.)[U]無能力；殘疾；無資格；限制']
# ['disapprove (vt.)(vi.)不贊成；不同意[+of]']
# ['disaster (n.)災難；不幸=calamity=catastrophe', 'disastrous (a.)災害的；災難性的=catastrophic']
# ['discharge (vt.)排出(液體、氣體等)；釋放；解雇；使免除；卸(貨物等)；開(砲等)', '(n.)[U]排出；釋放；解雇；卸貨；開砲']
# ['discipline (n.)[U]紀律；教養；訓練；懲罰', '(vt.)訓練；使有條不紊；懲戒', 'disciplinary (a.)訓練的；紀律的；懲戒的']
# ['disclose (vt.)使顯露；透露；公開=reveal=uncover', 'disclosure (n.)[U]揭發=revelation=exposure；']
# ['discomfort (n.)[U]不舒服；不安；使人不舒服的事', '(vt.)使不舒服；使不安']
# ['discreet (a.)謹慎的=prudent；考慮周到的；不引人注意的']
# ['discriminate (vi.)區別；辨出；有差別地對', '(vt.)區別；辨出；區別出', 'discriminating (a.)識別的；有差別', 'discrimination (n.)[U]辨別=distinction；辨識力；歧視=prejudice']
# ['disgrace (vt.)使丟臉；使蒙受恥辱；使失寵；貶黜', '(n.)[U]丟臉；恥辱=dishonor；失寵；丟臉的人事=scandal', 'disgraceful (a.)不名譽的；可恥的=shameful']
# ['dismantle (vt.)拆卸=disassemble；拆開；解散']
# ['dismay (n.)[U]驚慌=panic；沮喪；氣餒=frustration', '(vt.)使驚慌=frighten；使沮喪；使氣餒[+at/by]=frustrate']
# ['dispatch (vt.)派遣；發送；迅速處理；殺死', '(n.)[U]派遣；發送；急速；[C](公文)急件']
# ['dispense (vt.)分配；施給；執行；管理配(藥)', '(vi.)免除；省掉=[+with]', 'dispensable (a.)非必要的=unnecessary；可分配的；可寬恕的', 'dispenser (n.)藥劑師；分配者；施與者', 'dispensation (n.)[U][C]分配；施與(物)；[C]教規；']
# ['disperse (vt.)驅散=scatter；解散；傳播=spread', '(vi.)分散；散開']
# ['displace (vt.)(從原來的地方)移開=remove；撤換；取代=replace']
# ['displease (vt.)(vi.)得罪；觸怒=annoy']
# ['dispose (vt.)配置；處置；使有意於', '(vi.)處置；處理', 'disposal (n.)[U]處理；配置；出售', 'disposable (a.)可任意處理(使用)的；用完即丟棄的', 'disposition (n.)[C]性格；傾向；[U]處置(權)；清除；']
# ['disregard (vt.)不理會；漠視=ignore↔heed=pay no attention to', '(n.)[U]忽視；漠視=ignorance；不尊重']
# ['dissent (vi.)不同意；持異議[+from]', '(n.)[U]不同意；異議', 'dissident (a.)意見不同的；不贊成的', '(n.)意見不同的人；不贊成者']
# ['dissolve (vt.)分解；弄明白；解散=terminate；取消；感動', '(vi.)分解；溶解；解散；取消', '(n.)[U]畫面的溶暗；疊化畫面', 'dissolvent (a.)有溶解力的', '(n.)溶劑', 'dissolution (n.)[U][C]分解；溶解；解除；解散；消失']
# ['dissuade (vt.)勸(某人)勿做某事；勸阻=deter↔persuade']
# ['distort (vt.)扭曲；曲解=misrepresent；使失真', 'distortion (n.)[C][U]扭曲；變形；失真歪曲']
# ['distract (vt.)轉移；使分心[+from]↔attend to；使轉向；使錯亂', 'distraction (n.)[U]分心↔attention；注意力分散；困惑不安；[C]分散注意的事物；散心']
# ['distrust (vt.)不信任；懷疑', '(n.)[U]不信任；懷疑=doubt']
# ['disturb (vt.)妨礙；擾亂=intervene；使心神不寧', '(vi.)打擾；妨礙=hinder', 'disturbance (n.)[U][C]擾亂↔disorder；騷擾；憂慮；引起騷動的事物']
# ['diverge (vi.)分叉；偏離；背離；分歧；相異', '(vt.)使分岔；使偏離', 'divergence (n.)分歧背離；分離；相異', 'diverse (a.)不同的；多種多樣的=varied', 'diversity (n.)[U][C]差異；不同點；[U]多樣性[+of]=variety', 'divert (vt.)使轉向；使分心=distract；逗...開心', '(vi.)轉向；轉移', 'diversify (vt.)使多樣化', '(vi.)多樣化', 'diversion (n.)[U][C]轉向；轉換；[C]娛樂；消遣=pastime；[U]分散注意力=distraction']
# ['doctrine (n.)[U][C](宗教的)教義；信條=principle=dogma；政策學說；原理']
# ['document (n.)[C]公文；文件證件；單據', '(vt.)用文件證明；為…提供文件、證據', 'documentary (a.)文件的；記錄的；記實的', '(n.)[C]記錄影片；(電視等的)記錄節目']
# ['dome (n.)[C]圓屋頂；穹窿半球形物', '(vt.)加圓屋頂於...上；使成圓頂狀', '(vi.)成圓頂狀']
# ['donate (vt.)捐獻=contribute；捐贈=subscribe', '(n.)捐獻=contribution；捐贈=subscription', 'donation (n.)[U][C]捐獻；[C]捐贈物；捐款', 'donor (n.)[C]捐贈者=contributor']
# ['doom (n.)[U]厄運=fate；毀滅；末日審判', '(vt.)注定；命定；使失敗；使毀滅']
# ['dose (n.)[C](藥物)一劑；[口](尤指苦事的)一次', '(vt.)(按劑量)給…服藥；(分劑)給(藥等)', '(vi.)服藥', 'dosage (n.)(藥的)劑量；服法']
# ['drastic (a.)激烈的；猛烈的；嚴厲的=severe=harsh；極端的=extreme=radical', 'drastically (adv.)大大地；徹底地=thoroughly；激烈地=severely=radically']
# ['draw (vt.)(vi.)畫；繪製；拉長；拖長拔(出)；引出[+out]；開支票；領取；吸引；打成和局(平手)；推斷出；抽(籤)(draw-drew-drawn)', '(n.)[C]和局；抽簽；吸引人的人事物；拔', 'drawing (n.)[U]描繪；素描；[C]抽籤；提款', 'drawback (n.)[C]缺點=shortcoming；障礙=obstacle=barrier；撤回=withdrawal；短處=disadvantage；退稅', 'drawer (n.)[C]抽屜']
# ['dreary (a.)沉悶的；陰鬱的=gloomy；枯燥的=dull；令人生厭的']
# ['drizzle (vi.)下毛毛雨=sprinkle', '(n.)[U]毛毛雨']
# ['drought (n.)[C][U]乾旱；長期乾旱；(長期的)缺乏']
# ['dual (a.)兩的；雙倍的=double；雙重的', '(n.)[C]雙數；雙數詞', 'duet (n.)二重唱；二重奏']
# ['dubious (a.)半信半疑的[+about/of]=suspicious=incredulous；曖昧的=ambiguous；可疑的=doubtful=skeptical']
# ['dynamite (n.)[U]炸藥=explosive', '(vt.)用炸藥爆破；炸毀=blow up=blast', '(a.)[美]優質的']
# ['ebb (n.)[U]退潮；衰落', '(vi.)退潮；衰落[+away]']
# ['eccentric (a.)古怪的=bizarre=quirky；反常的', '(n.)[C]古怪的人']
# ['ecology (n.)[U]生態；生態學', 'ecological (a.)生態的', 'ecosystem (n.)生態系']
# ['ecstasy (n.)[U][C]狂喜=exultation=rapture；出神；入迷']
# ['edible (a.)可食用的']
# ['edit (vt.)編輯；校訂', 'edition (n.)[C]版本', 'editor (n.)[C]編輯者', 'editorial (a.)編輯的', '(n.)社論']
# ['electron (n.)[C]電子', 'electronic (a.)電子的', 'electronics (n.)電子學', 'electronically (adv.)以電子技術進行']
# ['eligible (a.)合格的=qualified；合法的=legal', '(n.)合格者']
# ['elite (n.)[C](集合名詞)菁英']
# ['eloquent (a.)雄辯的；口才流利的=rhetoric', 'eloquence (n.)[U]雄辯；口才=rhetoric']
# ['else (adv.)其他；另外', 'elsewhere (adv.)別處']
# ['embark (vi.)上船(飛機)=board；從事；著手', '(vt.)使上船；使從事']
# ['emigrate (vi.)移居他國↔immigrate', '(vt.)使移居', 'emigration (n.)[U][C]移居(出境)↔immigration', 'emigrant (n.)[C]移民；移出者↔immigrant']
# ['emphasize (vt.)強調；著重', 'emphasis (n.)[C][U]強調；重視；重點', 'emphases (n.)強調；重視；重點', 'emphatic (a.)強調的=forceful；顯著的=distinct']
# ['enact (vt.)制定(法規)=legislate；扮演', 'enactment (n.)[U]制定=legislation；[C]法令=regulation']
# ['enclose (vt.)包圍；圍繞[+with/by]', 'enclosure (n.)[U]包圍；[C]圍場；圍牆']
# ['encyclopedia (n.)[C]百科全書=encyclopaedia', 'encyclopedic (a.)百科全書的=encyclopaedic']
# ['endure (vt.)(vi.)持久；持續；忍耐；忍受=stand=bear=tolerate=put up with', 'endurance (n.)[U]耐力；忍受力=perseverance=tolerance', 'endurable (a.)可以忍受的=tolerant', 'enduring (a.)持久的']
# ['enhance (vt.)提高；增強=improve=elevate', 'enhancement (n.)[C][U]提高；增強=improvement']
# ['enlighten (vt.)↔迪；啟發=inspire=illuminate', 'enlightenment (n.)↔蒙；教化=illumination']
# ['enrich (vt.)充實；使豐富；使富裕', 'enrichment (n.)[U][C]充實；豐富']
# ['epidemic (n.)[C]傳染病=contagion', '(a.)傳染性的=contagious；流行的']
# ['episode (n.)[C]一回；一集；一章節']
# ['equate (vt.)使相等', 'equation (n.)[C]等式；方程式；[U][C]相等', 'equator (n.)赤道']
# ['equivalent (a.)等值的；相等的', '(n.)[C]等價物；相等物', 'equivalence (n.)相等；等值']
# ['erode (vt.)(水、風等)侵蝕', 'erosion (n.)[U]侵蝕']
# ['erupt (vi.)(火山)噴發；爆發', '(vt.)迸出；噴出', 'eruption (n.)[U][C]爆發=outbreak']
# ['escalate (vi.)逐步上升=ascend；升級', '(vt.)使逐步上升；使升級', 'escalator (n.)[C]電扶梯']
# ['essence (n.)本質；[U]精華', 'essential (a.)必要的；本質的', '(n.)要素；必備品']
# ['eternal (a.)永恆的=permanent=perpetual=everlasting；不朽的=immortal', 'eternity (n.)[U]永恆；不朽=immortality']
# ['ethics (n.)倫理學', 'ethical (a.)倫理的；道德的=moral']
# ['evacuate (vt.)撤退=retreat；使疏散', 'evacuation (n.)[U][C]撤退；疏散']
# ['evolve (vi.)演化；發展=develop', '(vt.)使逐步形成', 'evolution (n.)[U]進化；發展=development']
# ['excerpt (vt.)摘錄=extract；節錄；引用', '(n.)[C]摘錄=extract；節錄；引用[+from]']
# ['excessive (adv.)過度的；過分的；極度的']
# ['exclude (vt.)排斥；排除在外', 'exclusion (n.)[U]排斥；排除在外[+from]', 'exclusive (a.)排外的；獨占的[+of]↔inclusive[+of]']
# ['execute (vt.)實施；執行；將…處死', 'executive (a.)實行的；執行上的', '(n.)[C]執行者；行政官；主管', 'execution (n.)[U]實施；執行；[U][C]死刑']
# ['exert (vt.)盡力；運用；發揮=put forth', 'exertion (n.)[U][C]費力；運用']
# ['exotic (a.)異國風味的=foreign↔native']
# ['expedite (vt.)加快；促進', 'expedition (n.)[C]遠征隊；探險隊=exploration']
# ['expel (vt.)驅逐=dismiss；排出；開除[+from]', 'expulsion (n.)[U][C]驅逐=dismissal；開除[+from]']
# ['expert (n.)[C]專家；能手', '(a.)熟練的；精通的', 'expertise (n.)[U]專門技術；知識']
# ['expire (vi.)到期；期滿=terminate', '(vt.)呼出空氣', 'expiry (n.)期限', 'expiration (n.)終結；期滿；吐氣；死亡']
# ['explicit (a.)詳細的；清楚的=clear↔ambiguous=implicit']
# ['exploit (vt.)開發；開拓；剝削', 'exploitation (n.)[U]開發；開採']
# ['explore (vt.)探索；探險', 'exploration (n.)[U][C]探索；探險=expedition']
# ['exquisite (a.)精美的=delicate=refined；尖銳的；敏銳的=keen']
# ['extract (vt.)搾取；精煉；摘錄=quote', '(n.)[C]搾取；精煉；摘錄=excerpt']
# ['extracurricular (a.)課外的；業餘的', 'curricular (a.)課程的', 'curriculum (n.)[C]學校課程']
# ['eye (n.)[C]眼睛', '(vt.)看；注視', 'eyebrow (n.)[C]眉毛', 'eyelash (n.)[C]睫毛', 'eyelid (n.)[C]眼瞼', 'eyesight (n.)[U]視力；視野=sight=version', 'eyewitness (n.)[C]目擊者；見證人', '(vt.)親眼看見；目睹']
# ['fabulous (a.)驚人的=amazing=marvelous；難以置信的=unbelievable']
# ['facilitate (vt.)使容易=simplify↔complicated；促進；幫助=help=assist↔hinder', 'facility (n.)[U]能力；技能；設備=equipment=gear=device；工具；[C]場所']
# ['faction (n.)[C]政黨=party；[U]派系之爭；真人真事的小說(fact+fiction)', 'factious (a.)好搞派別活動的；源於派別的']
# ['faculty (n.)[C]官能[+of]；技能[+for/of]；系科院全體教職員=staff=personnel']
# ['family (n.)[C]家；家庭；家人家族=household=kin=folks', 'familiar (a.)世所周知的；熟悉的[+with/to]；常見的；親密的', 'familiarity (n.)[U]熟悉；通曉；親近；親暱；放肆', 'familiarize (vt.)使熟悉；使親近；使普及；使家喻戶曉']
# ['famine (n.)[C][U]饑餓；饑荒=starvation；…的荒[+of]']
# ['fascinate (vi.)有吸引力；迷人', '(vt.)迷住=attract=charm=enchant=mesmerize；強烈地吸引', 'fascinating (a.)迷人的=enchanting=charming；極美的；極好的=glamorous', 'fascination (n.)[U]魅力=glamour；迷戀=obsession；陶醉']
# ['feast (n.)[C]盛宴=banquet；筵席；享受；節日', '(vt.)盛宴款待；使…得到享受', '(vi.)參加宴會；享受[+on]=enjoy', 'feasible (a.)可實行的=practical=workable↔impractical；合理的=possible；合適的=suitable[+for]']
# ['federation (n.)[C]聯邦政府；聯邦制度；聯盟=league=alliance', 'federal (a.)國家的；聯邦政府的；聯邦制的=federated=allied=united', '(n.)[C]聯邦政府工作人員；(大寫)美國聯邦政府']
# ['feed (n.)[C](動物、嬰兒)一餐；[U]飼料；牧草', '(vt.)餵；飼養；提供=supply；滿足', '(vi.)吃；以…為食物[+]=eat=dine(feed-fed-fed)', 'feedback (n.)[U]反應=reaction=response']
# ['fertile (a.)肥沃的；能生育的；豐富的', 'fertilize (vt.)使肥沃；施肥；使受精', 'fertility (n.)[U]肥沃；繁殖力↔infertility', 'fertilizer (n.)[U][C]肥料=manure=compost；促進發展者；受精媒介物']
# ['fidelity (n.)[U]忠誠；忠貞=sincerity=faith=loyalty；精確；真實；真切']
# ['finite (a.)有限的=bounded=limited=restricted=definable=countable↔infinite', '(n.)有限；有限之物']
# ['fireproof (a.)防火的；耐火的', '(vt.)使具防火性能；為…安裝防火設施']
# ['flare (vi.)閃耀；爆發；突然發怒[+at]', '(vt.)使閃亮[+out]', '(n.)[C]閃耀的火光=flame=blaze=glow；照明彈']
# ['flee (vi.)逃=run away=escape；消失=vanish=disappear', '(vt.)逃離；逃避=run away=escape(flee-fled-fled)', 'fleet (n.)[C]艦隊', '(a.)快速的=rapid=swift=fast=quick；敏捷的=nimble', '(vi.)疾飛；掠過', '(vt.)消磨(時間)', 'fleeting (a.)轉瞬間的；短暫的']
# ['flick (n.)[C]輕彈聲；輕擊聲；(手指)輕彈', '(vt.)(vi.)輕打；輕彈[+off]', 'flicker (vt.)(vi.)閃爍不定；搖曳；撲動翅膀', '(n.)閃爍；閃現；[美]電影']
# ['fling (vt.)扔擲；拋；丟；猛烈地開、關(門、窗)；投身[+into]；破口大罵[+out](fling-flung-flung)', '(n.)[C]扔；擲；拋；一時的放縱']
# ['fluid (a.)流動的；流體的↔solid；液體的=liquid', '(n.)[C][U]流體；流質；液體=liquid']
# ['flutter (vi.)(鳥)振翼；(旗)飄動；顫動=tremor；(脈搏、心臟)不規則跳動=beat', '(vt.)振(翼)；拍(翅)；使焦急；使不安；使飄動=flap=tremble=move', '(n.)振翼；興奮；焦急；激動；飄動']
# ['fore- (prep.)早先；預先；之前；前部', 'forecast (vt.)預測=predict；預報；預言', '(vi.)作預報；進行預報', '(n.)[C]預報；預測；預料', 'foretell (vt.)預言；預示(foretell-foretold-foretold)', 'foreword (n.)序；前言', 'foresee (vt.)預見；預知(foresee-foresaw-foreseen)', 'foresight (n.)[U]遠見=perspective；先見之明；深謀遠慮=deliberation；展望', 'forefather (n.)祖先；前輩=ancestor', 'forego (vt.)放棄；發生…之前；走在…之前(forego-forewent-foregone)', 'foregoing (a.)前面的；前述的；上述的', 'forehead (n.)[C]額；前額']
# ['formidable (a.)可怕的；令人畏懼的=dreadful；難對付的=sticky；傑出的=phenomenal；巨大的=enormous=tremendous']
# ['formula (n.)[C]慣例=tradition=convention=custom；方案；配方；公式；處方=prescription', 'formulate (vt.)使公式化；用公式表示；配製；規劃']
# ['forsake (vt.)拋棄；背棄；摒棄；革除；離開(foresake-foresook-foresaken)', 'forsaken (a.)被拋棄的；被背棄的']
# ['forth (adv.)向前；向外；以後', 'forthcoming (a.)即將到來的；隨時可得的↔unavailable', 'forthright (adv.)直率的；明白無誤的；直截了當的=straightforward', 'forthwith (adv.)立即地=instantly=immediately=right away；毫不猶豫地=without hesitation', 'henceforth (adv.)今後；從今以後=from now on']
# ['fort (n.)[C]堡壘；要塞', 'fortify (vt.)築堡壘於；增強=strengthen=invigorate=reinforce↔weaken；加強；提高(食品)的營養價值', '(vi.)構築防禦工事；構築堡壘', 'fortification (n.)[U]設防；築城；築壘；防禦工事']
# ['foster (vt.)養育；領養=adopt；培養=cultivate↔restrain；促進=facilitate', '(a.)養育的；收養的=adoptive']
# ['fracture (n.)[C][U]破裂；斷裂；折斷；骨折；', '(vt.)(vi.)破裂；折斷；骨折；違反規定']
# ['fragile (a.)易碎的；易損壞的↔unbreakable；脆弱的；纖細的=slim=slender']
# ['fragment (n.)[C]碎片；破片；斷片；未完成部分', '(vt.)(vi.)成碎片']
# ['frail (a.)身體虛弱的↔vigorous；不堅實的；易損壞的↔sturdy；意志薄弱的=weak-minded', 'frailty (n.)[U]脆弱；虛弱；弱點；缺陷=defect']
# ['fraud (n.)[C][U]欺騙；詭計=scheme；騙局；']
# ['freak (n.)[C]任性的舉動；畸形的人(動、植物)', '(a.)反常的；怪異的=abnormal=eccentric=weird↔normal；稀奇的']
# ['fret (vt.)使苦惱；使煩躁；使發愁；侵蝕(fret-fretted-fretted)', '(vi.)苦惱；煩躁；發愁', '(n.)苦惱=agony；煩躁；擔憂；侵蝕=erosion；腐蝕', 'fretwork (n.)回紋裝飾；浮凸雕工']
# ['friction (n.)[U]摩擦；摩擦力；[U][C]不和；爭執=argument↔harmony']
# ['galaxy (n.)銀河']
# ['general (a.)一般的=common=vague=ordinary=universal；公眾的；籠統的=broad=widespread；總的', 'generalize (vi.)泛論；推斷', '(vt.)歸納；概括']
# ['generate (vt.)產生；發生(熱、電、光等)；造成；引起；生育；生殖']
# ['generator (n.)[C]發電機=dynamo；產生器']
# ['gene (n.)基因；遺傳因子', 'genetic (a.)起源的；發生的；基因的；遺傳的', 'genetics (n.)遺傳學']
# ['glamour (n.)[U]魅力；誘惑力；迷人的美；妖豔', '(vt.)使著魔；迷住；迷惑；美化[+up]', 'glamorous (a.)富有魅力的；迷人的=fascinating']
# ['glass (n.)[U]玻璃；[C]玻璃杯；一杯(的容量)', 'glasses (n.)眼鏡；雙筒望遠鏡', 'glassware (n.)玻璃器皿']
# ['glisten (vi.)閃耀；反光=glisten=sparkle=glitter=shine=glimmer=twinkle', '(n.)[S]閃耀；閃光']
# ['gloom (n.)[U]黑暗；陰暗；憂鬱的心情、氣氛', '(vi.)變陰暗；變陰沈', '(vt.)使暗；使陰沉；使憂鬱', 'gloomy (a.)陰暗的；陰沈的；陰鬱的；憂鬱的=dark=dim=dismal=dreary=somber=bleak=depressing=discouraging=melancholy↔cheerful']
# ['GMO(Genetically Modified Organism)(n.)基因改造生物']
# ['graph (n.)[C]圖；標繪圖；圖表=diagram=chart=outline；圖解']
# ['graphic (a.)生動的；寫實的；圖解的；座標式的']
# ['grill (n.)[C]烤架；燒烤的肉類食物', '(vt.)烤(食物)=grill=barbecue', '(vi.)被炙烤']
# ['grocer (n.)食品雜貨商', 'grocery (n.)[C]食品雜貨店；南北貨']
# ['grope (vi.)觸摸；探索；探求', '(n.)[C]觸摸；探索']
# ['guerrilla (n.)游擊戰；游擊隊', '(a.)游擊隊的']
# ['habit (n.)[C][U]習慣', 'habituate (vt.)使習慣於；上癮', 'habitat (n.)[C]棲息地；產地', 'habitant (n.)居民；居住者', 'habitation (n.)[U]居住；[C]住處；住所；住房']
# ['hack (vt.)批；砍[+at]；把…放在架上曬', '(n.)[C]批；砍；斧頭；曬架；曬磚臺']
# ['hacker (n.)駭客']
# ['hail (vt.)向…歡呼；擁立；擁戴', '(vi.)招呼；招呼致意；下冰雹', '(n.)[C][U]歡呼；打招呼；[U]冰雹']
# ['harass (vt.)使煩惱；煩擾；不斷騷擾', 'harassment (n.)[U]煩惱；煩擾；騷擾']
# ['hazard (n.)[C]危險=jeopardy=danger；危險之源', 'hazardous (a.)有危險的[+to]；冒險的=risky']
# ['hemisphere (n.)[C]地球半球']
# ['hereafter (adv.)此後；今後']
# ['heritage (n.)[U]遺產；世襲財產；繼承物；傳統']
# ['heroin (n.)海洛因']
# ['highlight (vt.)照亮；強調=spotlight=headline=emphasize=stress=mark', '(n.)[C]最明亮部分；最精彩的部分', 'highlighter (n.)螢光筆']
# ['honor (n.)[U]榮譽；面子；信譽', '(vt.)使增光；給…以榮譽；尊敬', 'honors (n.)優異成績；優等', 'honorary (a.)名譽上的；名譽職位的', 'honorable (a.)可尊敬的；高尚的；光榮的；榮譽的']
# ['hormone (n.)賀爾蒙']
# ['hospitable (a.)好客的；招待周到的；宜人的；親切的=friendly=welcoming=cordial', 'hospitalize (vt.)使住院治療']
# ['hospitality (n.)好客；殷勤招待；理解力；(對新思想等的)接受能力']
# ['hostile (a.)敵方的；懷敵意的', 'hostility (n.)[U]敵意↔approval；戰爭']
# ['humane (a.)有人情味的；人道的；人文的', 'humanly (adv.)從人的角度；人的知識範圍內', 'humanitarian (n.)[C]人道主義者；慈善家', '(a.)人道主義的；博愛的']
# ['humiliate (vt.)使蒙恥辱；羞辱；使丟臉↔honor', 'humiliation (n.)[U][C]丟臉；羞辱；蒙羞=shame=embarrassment', 'humility (n.)[U]謙卑；謙遜↔conceit']
# ['hunch (n.)[C]預感；直覺；瘤', '(vt.)使(背部)隆起；使成弓狀', '(vi.)向前移動；推進；隆起；彎成弓狀']
# ['hurdle (n.)[C]欄；障礙=obstacle=obstruction=hindrance；困難=difficulty', '(vt.)跨(欄)；克服(困難)']
# ['hygiene (n.)[U]衛生；衛生學；保健法', 'hygienic (a.)衛生的；保健的']
# ['hypocrite (n.)[C]偽善者；偽君子', 'hypocrisy (n.)[U]偽善；虛偽↔sincerity', 'hypocritical (a.)偽善的；虛偽的']
# ['hysterical (a.)歇斯底里的；情緒異常激動的']
# ['illuminate (vt.)照亮=light up；用燈裝飾[+with]；闡明=clarify；解釋；啟發', '(vi.)照亮；用燈裝飾；興奮', 'illumination (n.)[U]照明；燈飾；教化；解釋；啟發', '*tip*請參閱Around Words 第85組']
# ['illusion (n.)[C]錯覺；幻覺↔reality；假象；[C][U]幻想=delusion=imagination', 'illusionary (a.)虛幻的；幻想的=illusional=imaginary']
# ['immune (a.)免疫的；免於...的', '(n.)免疫者', 'immunity (n.)[U]免疫；豁免[+from]；[U][C]豁免權', 'immunize (vt.)使免除；使免疫']
# ['imperative (a.)必要的=vital=essential=necessary；緊急的；極重要的', '(n.)[C]命令；規則；[U]祈使語氣']
# ['implement (n.)工具=tool；器具；裝備；[C]手段', '(vt.)實施；執行；向...提供工具']
# ['imply (vt.)暗指；意味著；必然包含；必需', 'implication (n.)[U]牽連；涉及；捲入；[C][U]含意；言外之意；暗示']
# ['implicit (a.)不言明的↔explicit；含蓄的；內含的；固有的[+in]；無疑問的；無保留的；絕對的=absolute']
# ['impose (vt.)徵(稅)；把…強加於[+on/upon]', '(vi.)利用；佔便宜；欺騙[+on/upon]', 'imposition (n.)[U]徵收的稅；[C]不合理的要求；利用', 'imposing (a.)壯觀的=grand；莊嚴的；氣勢宏偉的']
# ['imprison (vt.)監禁；限制；束縛', 'imprisonment (n.)[U]監禁；關押；限制']
# ['incense (vt.)(常用被動)激怒；使憤怒；對…敬香', '(vi.)焚香；敬香', '(n.)[U]香；焚香的煙；香味；尊敬；恭維', 'incentive (n.)[U][C]刺激=stimulus；鼓勵；動機[+to]', '(a.)刺激的；鼓勵的；獎勵的']
# ['incident (n.)[C]事件', '(a.)易發生的；伴隨而來的', 'incidental (a.)附帶的；伴隨的；偶然發生的', '(n.)[C]附帶事件；偶然事件；雜項；雜費', 'incidentally (adv.)偶然地；順便提一句', 'incidence (n.)[U]落下；發生率；影響範圍']
# ['incline (vi.)(無進行式)傾斜；屈身；有意…；有…傾向；易於', '(vt.)(無進行式)使傾斜；使傾向於', '(n.)[C]傾斜；斜面；斜坡', 'inclination (n.)[C][U]傾向；愛好；[C]趨勢；傾斜']
# ['include (vt.)(無進行式)包括=contain=comprise=cover；包含；算入↔exclude', 'included (a.)被包括的', 'including (prep.)包括', 'inclusive (a.)包含的；包括的[+of]↔exclusive[+of]']
# ['indignant (a.)憤怒的；憤慨的', 'indignation (n.)[U]憤怒=resentment=rage；憤慨']
# ['inevitable (a.)必然(發生)的；不可避免的=unavoidable↔avoidable']
# ['infect (vt.)傳染；感染；污染[+with]', 'infection (n.)[U]傳染；[C]傳染病', 'infectious (a.)傳染的；有傳染性的；易傳播的']
# ['infer (vt.)推論=deduce；猜想；意味著', '(vi.)做出推論', 'inference (n.)[U]推論=conclusion；推斷；']
# ['ingenious (a.)足智多謀的=productive=masterful=creative=skillful；巧妙的=clever', 'ingenuity (n.)[U]足智多謀；巧妙']
# ['inhabit (vt.)佔據；棲息於；存在於；居住於=live/dwell/reside in=lodge', 'inhabitant (n.)[C]居民；居住者；棲居的動物', 'inhabitation (n.)[U]居住；棲息']
# ['inhere (vi.)生來即存在(於)；本質上即屬(於)', 'inherent (a.)內在的；固有的；與生俱來的=natural']
# ['initial (a.)開始的；最初的；在字開頭的', '(n.)[C]起首字母', 'initiate (n.)[C]接受初步知識者；新加入者', '(a.)接受初步知識的；新加入的', '(vt.)開始；創始；開始實施', 'initiation (n.)[U]開始；創始；開始實施；', 'initiative (n.)[C]主動的行動=lead；倡議；主動權；', '(a.)開始的；初步的；創始的']
# ['inject (vt.)注射；引入；投入[+into]', 'injection (n.)[C][U]注射=shot；引入；投入；']
# ['injustice (n.)[U]非正義；不公正↔justice；不公平；']
# ['innovate (vt.)創立；創始；改變；更動', '(vi.)革新；改革；創新', 'innovation (n.)[U]改革；創新；[C]新方法；新制度']
# ['inquire (vt.)訊問；查問；調查=investigation', '(vi.)詢問；調查[+about/into]', 'inquiry (n.)[C][U]詢問；探究；[C]調查；疑問', 'inquisitive (a.)好問的；好奇的[+about]；愛打聽的', 'inquiringly (adv.)愛追根究柢地；懷疑地']
# ['insight (n.)[C][U]洞察力=perception；眼光[+into]']
# ['insist (vt.)堅持；堅決認為；堅決主張；要求', '(vi.)堅持；堅決認為；強調[+on]', 'insistence (n.)[U]堅持；強調；主張；要求', 'insistent (a.)堅持的；引人注目的；急切的']
# ['install (vt.)任命；使就職[+in]；安裝↔removal；設置；安頓；安置', 'installation (n.)[U][C]就任；就職；就職典禮；', 'installment (n.)[U]就任；就職；安頓；安置；[U][C]安裝；設置；[C]分期付款；連載']
# ['institute (n.)[C]學校；學院；原則=principle；規則=regulation；慣例=custom=tradition=convention', '(vt.)創立；設立；制定；使就職', 'institution (n.)[C]制度；習俗；公共機構=facility=organization；公共團體建築物；']
# ['intact (a.)完整無缺的；原封不動的=untouched=complete=undamaged=unchanged']
# ['integrate (vt.)使成一體=combine↔divide；使結合；使合併；使完整；完善', '(vi.)成為一體；結合在一起', 'integral (a.)構成整體所必需的；不可缺的；完整的；整體的', 'integrity (n.)[U]正直；廉正；誠實=honesty']
# ['intellect (n.)[U][C]智力=intelligence；理解力；', 'intellectual (a.)智力的；理智的；聰明的']
# ['intersection (n.)[U]橫斷；交叉；[C]十字路口']
# ['interval (n.)[C]間隔=period=gap；距離[+between]', 'intervene (vi.)插進；介入[+between]；干擾；干涉；干預；調停[+in/between]；阻擾', 'intervention (n.)[U][C]插入；介入[+in]；調停；斡旋；干預=interference']
# ['intimate (a.)親密的；熟悉的[+with]', '(vt.)提示；暗示；通知；通告', 'intimacy (n.)[U]熟悉=familiarity；親密；親近']
# ['intimidate (vt.)威嚇；恫嚇；脅迫=threaten=menace', 'intimidating (a.)嚇人的；令人生畏的']
# ['intrude (vi.)侵入=invade；闖入=trespass；打擾', 'intrusion (n.)[U][C]侵入；闖入=invasion；打擾']
# ['invent (vt.)發明；創造；捏造；虛構', 'inventor (n.)[C]發明家；發明者；創作者', 'invention (n.)[U]發明；創造；創造力；[C]發明物；', 'inventory (n.)[C][U]存貨清單=catalog=list；財產目錄；存貨=stock；[C]詳細目錄', '(vt.)編制(詳細目錄等)；把…登入目錄']
# ['invest (vt.)投資；投入(時間、金錢)[+in]', '(vi.)投資；入股[+in]；賦予[+with]', 'investment (n.)[U][C]投資；投資額[+in]；', 'investigate (vt.)調查；研究', '(vi.)調查；研究[+into]', 'investigation (n.)[C][U]研究；調查[+on/of/into]']
# ['irony (n.)[U]反語；冷嘲；諷刺；嘲諷的話；', 'ironic (a.)冷嘲的；諷刺意味的']
# ['irritate (vt.)使惱怒；使難受；刺激↔ease=soothe', '(vi.)引起惱怒=annoy；引起不愉快', 'irritation (n.)[U]激怒=annoyance；惱怒；', 'irritable (a.)易怒的=touchy；急躁的；煩躁的；']
# ['joyful (a.)高興的；充滿喜悅的；使人高興的', 'joyous (a.)快樂的；高興的']
# ['kernel (n.)[C](果核、果殼的)仁；核心=core；(麥、玉米的)粒、子；要點[+of]', '(vt.)把…作核心；把…包在核內']
# ['kidnap (vt.)誘拐；綁架=abduct；劫持', 'kidnapper (n.)[C]綁票者；拐子']
# ['lament (vt.)為…悲痛；哀悼；痛惜；悔恨；悲嘆=mourn', '(vi.)哀悼；悲痛；悲嘆；痛哭', '(n.)[C]哀悼；悲痛之情；哀歌；悼辭=mourning']
# ['lava (n.)[U]熔岩；岩漿；火山岩']
# ['layman (n.)[C](未受神職的)一般信徒；門外漢；外行人↔professional']
# ['layout (n.)[C]安排；佈局；設計；(書籍、廣告)版面設計；版面編排；版面設計；規劃圖；陳列物；[U][C]陳列；陳列物']
# ['legendary (a.)傳說的；傳奇的；著名的=famous', '(n.)傳說集；聖徒傳']
# ['legislate (vi.)立法；制定、通過法律', '(vt.)用立法規定；經立法程序創制', 'legislation (n.)[U]法律；法規；立法；制定法律', 'legislative (a.)立法的；有立法權的；由法律規定的；立法機構的；依法執行的', '(n.)[C]立法機構', 'legislator (n.)[C]立法委員=lawmaker；國會議員']
# ['length (n.)[U][C]長度；(時間的)長短；期間；全長；全程[+of]；[C]段；節[+of]', 'lengthen (vt.)(vi.)使加長；使延長', 'lengthy (a.)長的；冗長的↔short=brief；囉嗦的', 'long (a.)長的；遠的；長久的；冗長的', '(adv.)長久地；始終', '(n.)[U]長時間；長時期；長褲', '(vi.)渴望[+for/after]', 'longhand (n.)[U]普通書寫；普通寫法', 'long-distance (a.)長距離的；長途的']
# ['liable (a.)容易…的=apt[+to]；會…的；應負稅的[+to]；可能的；負有法律責任的；有義務的[+for]；應受罰的；應服從的', 'liability (n.)[U]傾向[+to]；[U][C]責任；義務[+for]；']
# ['liberal (a.)開明的；心胸寬大的；慷慨的；大方的；豐富的；自由的', '(n.)[C]自由主義者', 'liberate (vt.)解放=release；釋放；使獲自由[+from]=free', 'liberation (n.)[U]解放[+from]；解放運動；釋出', 'liberty (n.)[U][C]自由；自由權；[U]許可；特權；活動於某地的權利']
# ['likely (a.)很可能的；適當的；正合要求的[+for]', '(adv.)很可能', 'liking (n.)[U]喜好；愛好[+for/to]', 'likelihood (n.)[U]可能；可能性[+of]', 'liken (vt.)把…比喻為[+to]', 'likewise (adv.)同樣地=similarly；相同地；也；亦']
# ['limousine (n.)[C]大型豪華轎車；大轎車= limo']
# ['line (n.)[C]線；線條；列；排；(等待順序的)行列；交通線；(詩文的)一行；外形；輪廓；(政治)路線、方針；界線；臺詞', '(vi.)排隊；排齊[+up]', '(vt.)用線標示；畫線於；沿…排列', 'liner (n.)[C]班輪；班機；襯裡；襯墊；眼線筆；眼線膏；畫線工具']
# ['linguist (n.)語言學者=polyglot', 'linguistic (a.)語言的；語言學的', 'linguistics (n.)語言學', 'lingual (a.)語言的；舌的']
# ['literature (n.)[U][C]文學；文學作品；文獻資料；', 'literary (a.)文學的；文言的；精通文學的', 'literal (a.)字面的；逐字的；如實的；不誇張的', 'literally (adv.)照字面地；實在地；不誇張地', 'literate (a.)能讀寫的；有文化修養的', '(n.)能讀寫的人；有文化修養的人', 'illiterate (a.)文盲的；知識淺陋的；未受教育的', '(n.)[C]文盲；無知的人', 'literacy (n.)[U]識字；讀寫能力↔illiteracy；知識']
# ['longevity (n.)[U]長命；長壽；壽命=life span']
# ['lounge (vi.)(懶洋洋地)倚；靠；躺；消磨時間；閒蕩；閒逛[+around/about]', '(vt.)懶散地混(時間)', '(n.)閒蕩；[C]休息室；候機室；躺椅']
# ['lunar (a.)月亮的；陰曆的；新月形的', 'lunatic (a.)瘋的=insane=mad；精神錯亂的', '(n.)[C]瘋子=madman=maniac', 'lunacy (n.)[U]精神失常；[C]愚蠢的行為']
# ['lure (n.)魅力；吸引力[+of]；誘惑物=temptation', '(vt.)引誘=tempt；誘惑=seduce']
# ['lush (a.)蒼翠繁茂的=dense；豐富的；多汁的', '(n.)[俚]酒；酒鬼；醉漢']
# ['lyric (a.)抒情的；適於歌唱的', '(n.)[C]抒情詩；抒情作品；歌詞', 'lyricism (n.)[U](詩歌的)抒情風格；熱情奔放', 'lyrical (a.)抒情詩般的；情感豐富的']
# ['magnitude (a.)[U]巨大；廣大；重大；重要性；規模=scale；[C]震級']
# ['malaria (n.)[U]瘧疾；混濁的空氣；瘴氣']
# ['manipulate (vt.)操作=control；(用權勢等)操縱；運用；巧妙地處理']
# ['manuscript (n.)[C]手寫本；手稿；原稿=script', '(a.)手寫的；原稿的']
# ['mar (vt.)毀損；玷污=stain；破壞=spoil=ruin', '(n.)[C]汙點=stain；缺點=shortcoming=disadvantage']
# ['mass (n.)團；塊；堆；片；群；眾多；大宗；大部分；主要部分；大眾；[U]質量', '(a.)大眾的；大量的；大規模的；全部的', '(vt.)(vi.)聚集起來', 'massive (a.)大量的；巨大的；大規模的', 'massacre (n.)[C]大屠殺=slaughter；殘殺；慘敗', '(vt.)屠殺=slaughter；使慘敗；徹底擊敗', '*tip*請參閱Around Words 第24組']
# ['mastery (n.)[U]支配；優勢；熟練；精通[+of/over]']
# ['material (a.)物質的；有形的；肉體的', '(n.)材料；物質；[U]素材；資料[+for]；工具；用具']
# ['mattress (n.)[C]褥墊；床墊']
# ['mechanism (n.)[C]機械裝置；機構；結構']
# ['medication (n.)[U]藥物治療；[C]藥物=medicine']
# ['medieval (a.)中世紀的；中古的；老式的；守舊的']
# ['meditate (vi.)沉思=contemplate=ponder；冥想；深思熟慮=deliberate', '(vt.)計劃=plan；打算；企圖', 'meditation (n.)[U]沉思=contemplation；冥想；深思熟慮=deliberation']
# ['melancholy (n.)[U]憂鬱=gloom；憂思；愁思', '(a.)憂鬱的=gloomy；鬱悶的']
# ['mellow (a.)(水果)成熟的；甘美的；(酒)芳醇的；(聲音)圓潤的；(光、色等)柔和的', '(vt.)使成熟=mature；使芳醇；使圓熟；使圓潤；使柔和', '(vi.)成熟；變圓潤；變柔和']
# ['mentality (n.)[U]精神性；智力=intellect；']
# ['merchandise (n.)[U]商品；貨物=goods', '(vt.)買賣；經營；促進…的銷售；推銷=sell', '(vi.)經商']
# ['merge (vt.)使(公司)合併=combine↔diverge；使融合；使同化', '(vi.)(公司等)合併；融合；同化']
# ['metaphor (n.)[C][U]隱喻；暗喻；象徵']
# ['metropolitan (a.)大都市的；首都的；首府的', '(n.)[C]大城市人']
# ['migrate (vi.)遷移=move；移居=emigrate', 'migration (n.)[U][C]遷徙；[C]移民群；移棲動物群', 'migratory (a.)遷移的；有遷移習慣的；流浪的']
# ['militant (a.)好戰的；激進的=aggressive', '(n.)[C]好鬥者；激進份子']
# ['mill (n.)[C]磨坊；麵粉廠；製造廠；工廠', '(vt.)碾碎；將…磨成粉', 'miller (n.)[C]磨坊主；製粉業者；碾磨工']
# ['mimic (vt.)戲弄；模仿；學…的樣子；與…極相似；呈現…的形象(mimic-mimicked-mimicked)', '(n.)[C]擅於模仿的人；小丑', '(a.)模仿的；假裝的；模擬的']
# ['miniature (n.)[C]縮樣；小型物；微型畫；小畫像', '(a.)小型的=tiny；微型的↔full-size；小規模的', '(vt.)是...的縮影']
# ['minimize (vt.)使縮減到最小↔maximize；低估；小看；極度輕視']
# ['miraculous (a.)奇蹟般的；驚人的=marvelous']
# ['mischievous (a.)惡意的=vicious=malicious；惡作劇的=prankish；淘氣的；調皮的=naughty']
# ['missionary (a.)傳教的；教會的；傳教士的', '(n.)[C]傳教士；鼓吹者；(外交)使節']
# ['mobilize (vt.)(vi.)動員↔immobilize；調動；使流通；使鬆動']
# ['modernization (n.)[U][C]現代化(的事物)']
# ['mold (n.)[C]模子；模型；鑄模；鑄型；鑄件；模製品；模式；[U]霉；霉菌', '(vt.)把…塑造成[+into]；鑄造；用模子做', '(vi.)發霉']
# ['momentum (n.)[U][C]動量；衡量；[U]氣勢；動力']
# ['monopoly (n.)壟斷；專賣；[C]壟斷商品；專利權(品)']
# ['monotony (n.)[U](聲音)單調；千篇一律；無變化↔variety=diversity', 'monotonous (a.)單調的；無抑揚頓挫的；無變化的；無聊的=unvaried↔varied']
# ['moral (a.)道德(上)的；講道德的；品性端正的；精神上的；心理上的；道義上的', '(n.)[C]寓意；道德；品行；風紀；倫理學；道德規範', 'morality (n.)[U]道德=ethics↔immorality；倫理；品行；道德觀；道德規範=ethic', 'moralize (vt.)教化', '(vi.)講道德；說教']
# ['morale (n.)[U]士氣；鬥志；道德；品行']
# ['motto (n.)[C]座右銘=maxim=creed；格言=saying；(書、扉頁上、章節前所引用) 警句；題詞；訓言']
# ['mournful (a.)悲慟的=sorrowful；憂傷的；悲觀的=pessimistic↔optimistic']
# ['mouthpiece (n.)[C](樂器的)吹口；(電話機的)送話口；(容器的)口；代言人=spokesperson']
# ['municipal (a.)市政的；市的；市立的；地方自治的；自治都市的；內政的']
# ['mute (a.)沉默的；啞的=dumb', '(n.)[C]啞巴', '(vt.)消除、減輕(聲音)；使(顏色)柔和']
# ['mythology (n.)[U](總稱)神話；神話學；[C]神話集']
# ['narrate (vt.)(vi.)講述；敘述=describe；作旁白', 'narrative (n.)[C][U]記敘文；故事；[U]敘述；講述', '(a.)敘事的=descriptive；敘事體的；故事形式的', 'narration (n.)[U]敘述；講述；記述體；解說；', 'narrator (n.)[C]解說者；敘述者；講述者']
# ['nationalism (n.)[U]民族主義；民族獨立運動']
# ['naval (a.)海軍的；軍艦的；船的']
# ['nature (n.)[U]自然；自然界；自然狀態；純真；簡樸；[C][U]天性本質；性質；類別', 'natural (a.)自然的；天生的；合乎常情的；正常的；不做作的；自然狀態的', '(n.)[C]天然物；自然的事情', 'naturally (adv.)天然地；天生地；自然地；當然=certainly=of course=for sure', 'naturalize (vi.)加入國籍；歸化；被吸收；被採納', '(vt.)使…入籍；使歸化；使適應；採納(外國語言、風俗習慣)；使不落俗套', 'naturalist (n.)博物學家；自然主義者']
# ['navel (n.)肚臍；中央；中心']
# ['navigation (n.)[U]航行=voyage；航海；航空；航運；航行學；領航；導航']
# ['negotiation (n.)協商=discussion；談判[+with]；']
# ['neon (n.)[U]氖；霓虹燈']
# ['neutral (a.)中立的=impartial↔partial；中性的；模糊的=vague=blurred=ambiguous；不確定的=uncertain', 'neutrality (n.)中立性；中立的狀態']
# ['newlywed (n.)新結婚的人；(常複數)新婚夫婦']
# ['newscaster (n.)新聞廣播員=newsreader']
# ['nominate (vt.)提名[+for/as]；任命；指定[+to/as]', 'nomination (n.)[C][U]提名；任命=appointment；', 'nominee (n.)[C]被提名人；入圍者', 'nominator (n.)提名者；推薦者；任命者', 'nominal (a.)名義上的；有名無實的；名詞性的；(金額)微不足道的；名字的；列名的', '(n.)[C]名詞性的詞']
# ['norm (n.)標準；規範；[C]定額；分配之工作量', 'normal (a.)正常的；正規的；精神正常的；身心健全的；垂直的；直角的', '(n.)標準；常態；[C]法線；正常人、事物', 'normality (n.)[U]常態；正常', 'normalize (vt.)使合標準；使正常化；使常態化']
# ['notorious (a.)惡名昭彰的[+for]=infamous', 'notoriety (n.)[U]惡名；臭名']
# ['nourish (vt.)養育=feed；滋養；施肥於=fertilize；支持=support；鼓勵=encourage；懷抱(希望、仇恨等)=harbor=bear', 'nourishment (n.)[U]營養品；食物；滋養=nutrition；養育；營養狀況', 'nourishing (a.)有營養的；滋養的=nutritious']
# ['nuisance (n.)[C]討厭的人(或事物)=annoyance；']
# ['nurse (n.)[C]護士；護理；照料；起源[+of]', '(vi.)護理；照料；當褓姆(或護士)', '(vt.)看護；護理；當…的保姆=babysit；培養；調治(疾病)；悉心照料', 'nursery (n.)[C]托兒所；育兒室；苗圃；養殖場', 'nurture (n.)[U]營養物；食物；培育；環境因素', '(vt.)養育=bring up；培育=cultivate；教養；給…營養；培植']
# ['nutrition (n.)[U]營養=nourishment；營養物；營養學', 'nutritious (a.)有營養的；滋養的=nourishing', 'nutrient (n.)[C]營養物；滋養物', '(a.)營養的；滋養的=nourishing']
# ['oblige (vt.)(vi.)迫使=compel；答應…的請求；施恩於；使…有義務=obligate', 'obliged (a.)有義務的；感激的', 'obligation (n.)[C][U]道義、法律的義務[+to]=duty=responsibility；[C]恩惠[+to/toward]；契約；證券；償付債務的款項', 'obligatory (a.)義不容辭的；有義務的=compulsory']
# ['obscure (a.)暗的；黑暗的；無名的；晦澀的；朦朧的；模糊的=unclear=vague=dim=blurred；難解的=ambiguous；隱匿的；偏僻的=remote', '(vt.)使變暗；遮掩；使不顯著；使難理解；混淆；使失色', 'obscurity (n.)[U]暗淡；朦朧；晦澀；難解；隱匿；不引人注目；[C]卑微者']
# ['offer (vt.)給予；提供；出示[+to]；貢獻；出(價)；試圖(做某事)；提議', '(vi.)提議；(機會等)出現；獻祭', '(n.)[C]提供；提議[+of]；出價', 'offering (n.)[U]提供；貢獻=contribution；[C]課程=course；捐獻物=donation；祭品=sacrifice；出售物']
# ['offspring (n.)子女；子孫=descendant↔ancestor；後代；產物']
# ['operate (vt.)(vi.)運作；營業；經營；起作用；動手術；執行任務；操作股票', 'operation (n.)[U]操作；運轉；營運；經營；', 'operational (a.)操作上的；經營上的；作戰上的', 'operator (n.)[C]操作者；接線生；施行手術的醫生；(企業)經營者；精明圓滑的人']
# ['oppose (vt.)(vi.)反對；反抗；妨礙+N/V-ing；使相對；使對抗[+to/against]', 'opponent (n.)[C]對手=rival；敵手=enemy=foe；反對者', '(a.)對立的；對抗的；敵對的；反對的', 'opposite (a.)相反的；對立的；相對的[+to]', '(n.)[C]對立面；對立物[+of]', '(prep.)在…對面', '(adv.)在對面；在對過', 'oppositely (adv.)相對地=conversely=on the contrary', 'opposition (n.)[U]反對=disapproval；敵對；對立']
# ['oppress (vt.)壓迫；壓制=repress；(常用被動)使煩惱；折磨[+by/with]；使鬱悶=depress', 'oppressed (a.)受壓迫的；受壓制的', 'oppression (n.)[U][C]壓迫=repression；壓制；沉悶=depression=dullness', 'oppressive (a.)壓迫的；壓制的；不公正的；專制的；沉重的；煩悶的']
# ['opt (vi.)選擇=choose', 'option (n.)[U]選擇=choice=alternative；選擇權；選擇自由；[C]選修科目；可選擇的東西；買賣的特權', 'optional (a.)隨意的↔compulsory；非必須的；選修的=elective', '(n.)選修科目']
# ['ordeal (n.)[C]嚴峻考驗=trial；苦難=hardship=mishap；折磨=torture']
# ['order (n.)[U]次序；整齊；有條理；秩序；規律；(良好的)狀況；命令；[C]訂購[+for]；等級；階層；界', '(vt.)命令；指揮；定購；點(菜)；整理；佈置；安排(vi)下命令；指揮；定購；點菜', 'orderly (a.)整齊的；有條理的；愛整潔的；守秩序的↔chaotic；和平的；值班的；有規律的=regular', '(n.)[C]護理員；傳令兵；[英]清道夫', '(adv.)按順序地；整齊地；有條理地']
# ['organ (n.)[C]器官；機構；機關；管風琴；風琴', 'organic (a.)器官的；有機體的；組織的；基本的；構成整體所必需的；施用有機肥料的', 'organism (n.)[C]生物=creature；有機體；有機組織']
# ['origin (n.)[C][U]起源；起因=beginning；', 'original (a.)最初的；原始的=primitive；原作的；有獨創性的=creative；新穎的', '(n.)[C]原物；原著；原文；有獨創性的人', 'originally (adv.)起初=at first；獨創地；新穎地', 'originate (vi.)發源；來自；產生[+in/from/with]；創始=create；開始=begin', '(vt.)引起；發明；創作', 'originality (n.)[U]創造力=creativity；獨創性；創見；創舉；新穎=novelty；奇特']
# ['outbreak (n.)[C]爆發[+of]；暴動=outburst']
# ...
# ['prize (n.)[C]獎=award；獎品；獎金', '(vt.)重視=value；估價；評價；捕獲']
# ['produce (vt.)製造=manufacture；出示=show', '(n.)[U]產品；農產品', 'product (n.)[C]產品；產物；成果作品', 'production (n.)[U]生產；製作；演出；產量；成果', 'productive (a.)生產的；多產的；肥沃的', 'productivity (n.)[U]生產力；生產率；豐饒；多產', 'producer (n.)[C]生產者；(電影、電視片等)製作人']
# ['progress (n.)[C][U]前進；進步=improvement', '(vi.)前進；上進；提高；進步=improve；進行=proceed↔discontinue', 'progressive (a.)進步的=advanced；漸進的=gradual']
# ['project (vi.)投射；突出', '(n.)[C]方案；企劃；國民住宅', 'projection (n.)[C][U]規劃；設計']
# ['promise (n.)[C]承諾=vow；[U]約定；', '(vt.)允諾=allow', 'promising (a.)有希望的；有前途的；大有可為的']
# ['pronounce (vt.)(vi.)發音=sound', '(vt.)宣布', 'pronunciation (n.)[C][U]發音；讀法']
# ['propose (vt.)提議=recommend= suggest；求婚', 'proposal (n.)[C]建議；計劃；提案；求婚', 'proposition (n.)[C]建議；命題；論點；事業']
# ['protect (vt.)保護=defend；防護', 'protective (a.)保護的；防護的；關切保護的', 'protection (n.)[U]保護；防護']
# ['provide (vt.)提供=offer；供給=supply；準備,']
# ['pudding (n.)[C][U]布丁；[S]布丁狀物']
# ['pump (n.)[C]泵；抽吸', '(vt.)抽(水)；打(氣)；盤問[+out]', '灌注(知識等) [+ into/upon]']
# ['pumpkin (n.)[C][U]南瓜']
# ['punish (vt.)懲罰=discipline；受損', 'punishable (a.)該罰的；可罰的', 'punishment (n.)[U][C]懲罰=penalty，discipline']
# ['pupil (n.)[C]小學生；弟子；被監護人；']
# ['puppet (n.)[C]木偶；玩偶；傀儡']
# ['puppy (n.)[C]幼犬；幼小動物']
# ['purse (n.)[C](女用)錢包=wallet男用錢包', 'purse-proud (a.)以富誇耀的']
# ['puzzle (vt.)使迷惑=confuse；使為難；苦思而得出[+ out]', '(vi.)感到迷惑[+ at]；苦思', '(n.)[C]謎=riddle；難題；難以理解之事', 'puzzlement (n.)迷惑；費解；謎']
# ['quality (n.)[U]質；質量']
# ['quantity (n.)[U]量；[C]數量=amount；大宗[+of]']
# ['quarter (n.)[C]四分之一；十五分鐘；(城市中的)區；一區的居民']
# ['quit (vt.)離開；放棄=give up；停止=cease(quit-quit-quit)']
# ['quiz (vt.)問東問西；小測驗=examine(quiz-quizzed-quizzed)', '(n.)[C]小考=test (pl. quizzes)']
# ['rabbit (n.)[C]兔子']
# ['rain (n.)[U]雨', '(vi.)下雨', 'rainy (a.)下雨的；多雨的', 'rainfall (n.)[U][C]降雨；降雨量', 'rainbow (n.)[C]彩虹', 'raincoat (n.)[C]雨衣']
# ['range (vt.)排列=arrange；分布=extend', '(n.)[C]範圍=scope']
# ['rapid (a.)快速的=quick；陡峭的', 'rapidity (n.)[U]迅速']
# ['rare (a.)稀罕的=scarce；珍貴的；三分熟', 'rarely (adv.)稀有地=hardly=scarcely=barely；很不常地=seldom']
# ['rather (adv.)稍微；有幾分；相當=quite']
# ['real (a.)真實的；逼真的', 'really (adv.)真正的', 'realize (vt.)使…成真=fulfill；實現；了解', 'realization (n.)了解；認知；實現', 'realistic  (a.)現實的；逼真的；實際的', 'reality (n.)[U] 真實性；事實=fact']
# ['recent (a.)最近的；近代的', 'recently (adv.)最近=lately']
# ['record (n.)[C]紀錄', '(vt.)紀錄=register', 'recording (n.)[U]錄音；錄影', 'recorder (n.)[C]錄音機']
# ['rectangle (n.)[C]矩形；長方形']
# ['refrigerator (n.)[C]冰箱=fridge；冷凍庫', 'refrigerate (vt.)冷藏']
# ['refuse (vi.)(vt.)拒絕=reject', 'refusal (n.)[U][C]拒絕']
# ['regard (vt.)把…看作=consider；尊重；問候', '(n.)[U][C]問候；注意=care；尊敬', 'regarding (a.)關於', 'regardless (a.)不注意的']
# ['region (n.)[C]地區=area；領域', 'regional (a.)地區的']
# ['regulate (vt.)管理；控制；使規則化', 'regular (a.)規律的↔irregular；定期的']
# ['reject (vt.)拒絕=turn down↔accept；駁回', 'rejection (n.)[C][U]拒絕；否決']
# ['relate (vi.)有關', '(vt.)敘述', 'relative (a.)相對的；相關的', '(n.)[C]親戚', 'relation (n.)[U]關係；關聯', 'relativity (n.)[U]相關性；相對性', 'relationship (n.)[C][U]關係；人際關係']
# ['repeat (vt.)(vi.)重複；重作', 'repetitive (a.)反覆的；嘮叨的', 'repetition (n.)[C][U]重複；反覆']
# ['reply (vi.)回覆(reply-replied-replied)', '(n.)[C]答覆=response']
# ['report (vt.)(vi.)報告；報導', 'reporter (n.)[C]記者=journalist']
# ['require (vt.)需要=need；要求', 'requirement (n.)[C]要求；必要條件=essential']
# ['respect (vt.)尊重', '(n.)[U]尊重↔disrespect；[C]方面=way', 'respective (a.)個別的；各自的', 'respectively (adv.)分別地；個別地', 'respectful (a.)尊重的；禮貌的[+to]', 'respecting (prep.)關於']
# ['responsible  (a.)有責任的=duty-bound；引起…的', 'responsibility (n.)[U]責任']
# ['restroom (n.)廁所；盥洗室']
# ['result (vi.)發生；導致=end up', '(n.)[C]結果=consequence', 'resultant (a.)結果帶來的']
# ['review (vt.)評論；複習=[英]revise；調查=survey', '(n.)[U][C]評論=criticism；複習；調查']
# ['rich (a.)富有的；富饒的；有錢的', 'riches (n.)財富；財產']
# ['rock (n.)[C]岩石', '(vt.)搖動=shake；使震驚', 'rocky (a.)多岩石的']
# ['role (n.)[C]角色=character']
# ['royal (a.)皇家的=noble', 'royalty (n.)[U] 王位；皇室；版稅']
# ['rude (a.)粗野的=impolite；簡陋的=shabby']
# ['rule (n.)[C]規則；規定', '(vt.)(vi.)統治；支配', 'ruler (n.)[C]統治者=leader；尺', 'ruling (a.)統治的', '(n.)[U]裁定']
# ['rush (vi.)衝進=dash；倉促行動=hurry', '(n.)[C][U]衝；蜂擁而至']
# ['safe (a.)安全的↔dangerous', '(n.)[C]保險櫃(箱)=depository', 'safety (n.)[U]安全', 'safeguard (vt.)為…提供防護措施；護送；保護', '(n.)[C]護衛者；保護；防衛[+against]']
# ['sail (vi.)揚帆行駛；航行=voyage', '(vt.)乘船經過；駛船', '(n.)[C]帆；帆船', 'sailing (n.)[U]航海術，[C]航海；航行', 'sailor (n.)[C]航海者；水手']
# ['salad (n.)沙拉；涼拌生菜；雜燴']
# ['salt (n.)[U]鹽', '(vt.)給…加鹽；用鹽醃[+down]', 'salty (a.)有鹽味的；鹹味濃的']
# ['sample (n.)[C]樣品；樣本', '(vt.)抽樣試驗；品嘗']
# ['sandwich (n.)[C]三明治']
# ['satisfaction (n.)[U]稱心；使人滿意之物', 'satisfactory (a.)令人滿意的', 'satisfy (vt.)使滿意[+with]', '(vi.)令人滿意(satisfy-satisfied-satisfied)']
# ['saucer (n.)[C]茶托；淺碟']
# ['science (n.)[C][U]科學；技術', 'scientific (a.)科學的；科學上的', 'scientist (n.)[C]科學家']
# ['scissor (vt.)用剪刀剪開', 'scissors (n.)剪刀']
# ['score (n.)[C]得分；樂譜', '(vt.)(vi.)贏得分數']
# ['screen (n.)[C]螢幕；屏風；紗窗', '(vt.)掩蔽；遮護；包庇[+from]；放映；拍攝；審查；選拔', '(vi.)上銀幕']
# ['search (vt.)(vi.)搜尋；搜查', '(n.)[C]搜尋；研究', 'searching (a.)有洞察力的；徹底的']
# ['secret (n.)[C]秘密；秘訣', '(a.)機密的；私下的；隱蔽的']
# ['secretary (n.)[C]秘書']
# ['section (n.)[C]部分；欄；區域；切片', '(v.)把….分段']
# ['select (vt.)選擇', 'selection (n.)[C][U]選擇', 'selective (a.)有選擇性的']
# ['semester (n.)[C]學期']
# ['separate (vt.)(vi.)分離；使分散', '(a.)分離的；分離的', 'separation (n.)[C][U]分開；分離', 'separated (a.)分居的']
# ['serious (a.)嚴重的；嚴肅的；認真的', 'seriously (adv.)嚴肅地']
# ['servant (n.)[C]僕人', 'serve (vt.)為…服務=assist；供應(飯菜)', 'service (n.)[U]服務；招待；公共事業=facility；幫助', 'serving (n.)(食物)一份']
# ['settle (v.)解決；定居；安頓；平靜', 'settlement (n.)[C][U]解決；殖民地；定居']
# ['share (n.)[C][U]份；配額；貢獻', '(vt.)分派；分擔；共有', '(vi.)參與某事']
# ['shelf (n.)[C]書架；架子上的東西']
# ['shell (n.)外殼；砲彈', '(v.)脫落；去殼；撿貝殼']
# ['shock (n.)[C][U]震動；衝擊；觸電', '(vt.)震動；使人感到震驚']
# ['shoot (vt.)(vi.)發射；開槍；拍攝', 'shot (n.)[C]射擊；一擊；注射(shoot-shot-shot)']
# ['shorts (n.)短褲']
# ['shower (n.)[C]淋浴；驟雨；一大批；大量', '(vi.)(vt.)淋浴；下陣雨；傾注']
# ['shrimp (n.)[C]小蝦；無足輕重的人', '(vi.)捕蝦']
# ['side (n.)[C]面；旁邊；觀點；方面', 'sidewalk (n.)[C]人行道']
# ['sign (vi.)(vt.)簽名', '(n.)[C]符號；標誌；暗號；徵象', 'signal (n.)[C]信號；暗號；標誌', 'signature (n.)[C]簽名；特徵']
# ['silence (n.)[U]寂靜；沉沒', '(vt.)使安靜；壓制；壓下意見', 'silent (a.)沉默的；寡言的；寂靜無聲的']
# ['silk (n.)絲；絲織品', '(vi.)(玉米)抽穗絲', '(a.)絲的']
# ['similar (a.)相像的；類似的[+ to]', 'similarity (n.)[U]類似', '(n.)[C]相似點', 'similarly (adv.)同樣地']
# ['simple (a.)簡單的；單純的；完全的；愚笨的↔complicated', 'simplicity (n.)[U]簡單；樸素；無知', 'simplify (vt.)簡單；精簡；使單純', 'simply (adv.)簡單地；樸素地；純粹地']
# ['single (a.)單一的；孤單的；唯一的', '(n.)[C]單身者；單打比賽', '(vt.)選出；挑出']
# ['sink (vi.)(vt.)下沉；倒下(sink-sank-sunk)', '(n.)[C]洗滌槽；陰溝']
# ['skill (n.)[C][U]技術；技巧', 'skillful (a.)有技術的；熟練的；製作精巧的']
# ['skin (n.)[C][U]皮膚；皮=covering', '(vt.)剝…的皮；去…的殼；擦破…上的皮膚；在…上植皮', '(vi.)植皮；癒合；脫皮(skin-skinned-skinned)', 'skinny (a.)皮的；極瘦的；吝嗇的']
# ['skirt (n.)[C]裙子']
# ['sleep (vt.)(vi.)睡覺(sleep-slept-slept)', '(n.)[U]睡覺；死亡', 'sleepy (a.)想睡的；昏昏欲睡的']
# ['slender (a.)修長的；苗條的；微薄的']
# ['slide (vi.)滑動；悄然經過(slide-slid-slid)', '(n.)[C]滑；下落；幻燈片；雪崩；滑坡']
# ['slim (a.)纖細的；渺茫的；微薄的', '(vi.)減輕體重[+ down]']
# ['slip (vi.)滑動；滑跤(slip-sipped-slipped)', '(n.)[C]滑跤；滑落']
# ['slipper (n.)[C]拖鞋']
# ['snack (n.)[C]點心', '(vi.)(vt.)吃點心；吃快餐[+ on]']
# ['snail (n.)[C]蝸牛']
# ['snow (n.)[U]雪=flake', '(n.)下雪季節', '(vi.)下雪；雪片似地落下', 'snowy (a.)下雪的；潔白無瑕的']
# ['so (adv.)如此；那樣地；也', '(conj.)因此；所以']
# ['soccer (n.)[U]足球']
# ['sociable (a.)好交際的；友善的', 'social (a.)社會上的；社交的；喜歡交際的', '(n.)[C]聯誼會', 'society (n.)[U][C]社會']
# ['sock (n.)[C]短襪；儲蓄罐', '(vt.)儲蓄；投擲']
# ['soldier (n.)[C]士兵；戰士', '(vi.)服兵役']
# ['solution (n.)[C]解答；解決辦法；[U]溶解', 'solve (vt.)解決；解答；解釋']
# ['somebody (n.)[C]重要人物；大人物', '(pron.)某人；有人']
# ['somewhere (adv.)在某處']
# ['sort (n.)[C]種類', '(vi.)分類']
# ['source (n.)[C]根源；來源', '(vt.)(從特定來源)獲得(商品、零件)', '(vi.)從其他公司、國家獲得零件、材料等；開源']
# ['south (n.)[U]南方', '(a.)南方的', '(adv.)朝南方']
# ['soybean (n.)大豆；黃豆', 'soybean milk (n.)豆漿']
# ['speak (v.)說話；談論；發表演說；傳達=say', 'speaker (n.)[C]演講者', 'speaking (n.)[U]言談；演講', '(a.)說話的；說某種語言的']
# ['speed (n.)[U][C]速度；快速', '(vi.)迅速前進(speed-sped-sped/speed-speeded-speeded)']
# ['spell (n.)[C]一段時間；魔法=charm', 'spelling (n.)[U]拼字']
# ['spider (n.)[C]蜘蛛']
# ['spinach (n.)[U]菠菜']
# ['spirit (n.)[U]靈魂；情緒', 'spiritual (a.)精神上的']
# ['spot (n.)斑點；污點；場所；位置', 'spotlight (n.)[C]聚光燈；公眾注意的中心', '(vt.)聚光照明；使公眾注意']
# ['spread (vt.)伸展；傳播；張開；塗(spread-spread-spread)']
# ['spring (n.)[C][U]春天；跳躍', '(n.)[C]彈簧；根源', '(vt.)(vi.)跳躍；彈起；源於(spring-sprang-sprung)']
# ['square (n.)[C]正方形；廣場', '(a.)正方形的', '(vt.)使成正方形；[數]使成平方；求…的面積；使一致；使挺直；使平正', '(vi.)成正方形；成直角；一致；相符[+with]']
# ['squirrel (n.)松鼠', '(vt.)把….藏起來[+away]']
# ['stage (n.)[C]舞台', '(vt.)把…搬上舞台；籌畫']
# ['stamp (n.)[C]郵票；印花；圖章；標誌', '(vt.)貼郵票；蓋章', '(vi.)踩']
# ['standard (n.)[C][U]標準；規格', '(a.)標準的；權威的；一般性的']
# ['steak (n.)牛排']
# ['steal (vt.)(vi.)偷竊；悄悄行動(steal-stole-stolen)']
# ['steam (n.)[U]蒸氣；精力', '(vi.)蒸；冒水氣', 'steamer (n.)汽船；輪船', 'steamboat (n.)[C]汽船', 'steamship (n.)[C]輪船']
# ['steel (n.)鋼鐵', '(vt.)使…堅強；下定決心', '(a.)如鋼鐵般的']
# ['stick (vt.)刺；黏(stick-stuck-stuck)', '(n.)[C]棍；棒', 'sticky (a.)黏的；棘手的', 'sticker (n.)尖刀；屠夫；貼紙；標籤']
# ['stomach (n.)[C]胃；下腹=belly', 'stomachache (n.)[C]胃痛；腹痛']
# ['storm (n.)[C]暴風雨', '(vi.)起暴風雨', 'stormy (a.)暴風雨的']
# ['stove (n.)[C]火爐；暖爐']
# ['straight (a.)正確的；直接的；正直的', 'straighten (vt.)弄直；整頓；澄清；改正']
# ['strange (a.)不認識的=unfamiliar；罕見的；奇怪的=unusual', 'stranger (n.)[C]陌生人；外行人']
# ['straw (n.)[U]稻草；麥桿', '(n.)[C]吸管']
# ['strawberry  (n.)[C]草莓']
# ['stream (n.)[C]小河；溪流', '(vi.)流動；湧進']
# ['stress (vi.)強調', '(n.)[U]壓力；緊迫；重要性', 'stressful (a.)充滿緊張感的；充滿壓力的']
# ['stretch (v.)伸展；誇大', '(n.)伸展；彈性；一段時間', '(a.)可伸縮的']
# ['strict (a.)嚴格的；精確的；完全的']
# ['strike (vt.)打擊；攻擊；敲鐘(strike-struck-struck/stricken)', '(n.)[C]打擊；罷工；罷課', 'stricken  (a.)受傷的；被擊中的', 'striking (a.)引人注目的；顯著的']
# ['string (n.)線；細繩；帶子', '(vt.)串起；懸掛；使緊張', '(vi.)連成一串(string-strung-strung)']
# ['struggle (vi.)掙扎；搏鬥', '(n.)[C]掙扎；費力']
# ['subject (n.)[C]主題；科目', 'subjective (a.)主觀的↔objective']
# ['subtract (vt.)減；減去', '(vi.)做減法', 'subtraction (n.)減', 'subtractive (a.)減去的；有負號的']
# ['subway (n.)[C]地鐵']
# ['succeed (vi.)成功(succeed-succeeded-succeeded)']
# ['success (n.)[U]成功', 'successful (a.)成功的']
# ['sudden (a.)突然的', 'suddenly (adv.)突然地']
# ['suit (n.)[C](一套)衣服', '(vt.)(vi.)適合；中意']
# ['sunny (a.)陽光充足的；明媚的；快活的']
# ['supermarket (n.)超級市場']
# ['supply (vt.)提供(supply-supplied-supplied)', '(n.)[U][C]供給；儲存']
# ['support (vt.)支持；支撐；養活；證明', '(n.)[U][C]支持；支撐']
# ['surface (n.)[C]外觀；表面；水面']
# ['survive (vt.)(vi.)生存']
# ['swallow (vt.)吞嚥；嚥下；吞沒；忍受', '(n.)[C]燕子']
# ['swan (n.)天鵝', '(v.)閒蕩；遊蕩[+off]']
# ['sweat (vi.)(vt.)流汗(sweat-sweat/ed-sweat/ed)', '(n.)[U]汗水', 'sweater (n.)[C]毛衣']
# ['sweep (vt.)(vi.)打掃；掠過(sweep-swept-swept)', '(n.)[C]掃除']
# ['swing (vi.)搖擺地走；轉身(swing-swung-swung)', '(n.)[C]鞦韆']
# ['symbol (n.)[C]象徵；符號', 'symbolize (vt.)象徵；用符號表示', 'symbolic (a.)象徵的；符號學的']
# ['talent (n.)[U][C]才華']
# ['talk (vi.)(vt.)談論=discuss；說話=speak', '(n.)談論=conversation', 'talkative (a.)喜歡說話的；多話的']
# ['tangerine (n.)[C]橘子']
# ['tank (n.)[C]貯水槽；坦克']
# ['tape (n.)[U]膠帶', '(n.)[C]錄影帶', '(vt.)錄影；錄音']
# ['target (n.)[C]對象；目標']
# ['task (n.)[C]任務；工作；苦差事']
# ['tasty (a.)有品味的；好吃的；高雅的']
# ['team (n.)隊；組', '(v.)組成一隊', '(a.)團隊的']
# ['tear (vt.)撕裂；扯破；含淚(tear-tore-torn)', '(n.)[C]撕；扯；眼淚']
# ['teenage (a.)十幾歲的', 'teenager (n.)[C]十幾歲的少年']
# ['telephone (n.)電話', '(v.)打電話']
# ['television  (n.)電視；電視業']
# ['temple (n.)廟宇；神殿']
# ['tennis (n.)[U]網球運動']
# ['tent (n.)[C]帳篷；帷幕']
# ['term (n.)[C]任期；學期；關係']
# ['terrible (a.)可怕的；駭人的', 'terrific (a.)很棒的']
# ['test (n.)[C]測驗', '(vt.)試驗；檢驗；化驗；分析']
# ['textbook (n.)[C]教科書；課本']
# ['theater (n.)[C]電影院；劇場']
# ['therefore (adv.)因此；所以']
# ['thick (a.)厚的；濃的；濁的；充滿的', 'thicken (vt.)使變厚；使變濁；使不清楚']
# ['thief (n.)[C]小偷', 'thieve (vt.)偷竊', '(vi.)做賊']
# ['thin (a.)薄的；瘦的']
# ['thirsty (a.)口渴的；渴望的']
# ['throat (n.)[C]喉嚨']
# ['through (prep.)通過；整個…之中；經由；由於…', '(adv.)通過；完成；自始至終；全程地']
# ['throughout (adv.)至始至終；到處', '(prep.)遍及；貫穿']
# ['thumb (n.)[C]拇指']
# ['thunder (n.)雷；雷聲；威嚇；譴責', '(vi.)打雷', '(vt.)發出轟轟聲']
# ['tip (n.)[C]尖端；小費；提示', '(vt.)翻倒；給…小費(tip-tipped-tipped)', 'tiptoe (n.)[C]腳尖']
# ['title (n.)[C]標題；頭銜']
# ['toast (n.)吐司', '(vt.)(vi.)烤；烘']
# ['toe (n.)腳尖；腳趾', '(vt.)腳踢；腳戳', '(vi.)用腳尖走路']
# ['toilet (n.)[C]盥洗室；洗手間；沖水式馬', 'toiletry (n.)化妝品']
# ['tomato (n.)[U][C]番茄']
# ['tongue (n.)[C]舌頭']
# ['tooth (n.)[C]牙齒']
# ['topic (n.)[C]主題']
# ['tour (n.)[C]旅行；旅遊；巡迴演出', '(vi.)(vt.)旅行；作巡迴演出', 'tourist (n.)[C]旅遊者', 'tourism (n.)旅遊業；觀光業']
# ['towel (n.)[C]毛巾；抹布']
# ['tower (n.)[C]塔；塔臺']
# ['track (vt.)追蹤；走過', '(n.)[C]足跡；路徑；軌道']
# ['trade (vt.)交換', '(n.)[U]貿易；交易', 'trademark (n.)[C]商標；標記']
# ['tradition (n.)[U][C]傳統；慣例', 'traditional (a.)傳統的；慣例的']
# ['traffic (n.)[U]交通；交易；生意']
# ['trap (vt.)(vi.)設陷阱；使落入圈套', '(n.)[C]陷阱(trap-trapped-trapped)']
# ['travel (n.)[U]旅行', '(vi.)旅行']
# ['treasure (vt.)珍愛；珍藏', '(n.)[U]財富', '(n.)[C]貴重物品', 'treasury (n.)[C]寶庫；金庫；資金']
# ['treatment (n.)[U]待遇；治療法', 'treaty (n.)[C]條約；協定']
# ['trial (n.)[C][U]試驗；磨練；審判']
# ['triangle (n.)[C]三角形']
# ['trick (n.)[C]詭計；花招；手法', '(vt.)(vi.)哄騙', 'tricky (a.)狡猾的；機警的']
# ['trousers (n.)褲子；長褲']
# ['truck (n.)[C]貨車；卡車']
# ['trumpet (n.)[C]小號；喇叭', '(vt.)大聲宣告；吹噓']
# ['trust (n.)[U]信賴；託付', '(vt.)(vi.)信賴；信任']
# ['truth (n.)[U][C]事實']
# ['tube (n.)[C]管子；筒', '(vt.)用管輸送；給…裝上管子']
# ['tunnel (n.)[C]隧道；地道', '(vt.)(vi.)挖掘隧道；鑿']
# ['turkey (n.)火雞']
# ['turtle (n.)海龜']
# ['type (n.)[C]類型；典型；模範；字體', '(vi.)打字']
# ['typhoon (n.)[C]颱風']
# ['ugly (a.)醜的；可憎的']
# ['umbrella (n.)[C]雨傘；保護（傘）']
# ['underwear (n.)[C]內衣']
# ['uniform (n.)[C]制服；軍服']
# ['upon (prep.)在…之上；依據']
# ['upper (a.)上面的；較高層的']
# ['use (vt.)使用；發揮=utilize', 'used (a.)習慣於；用舊了的', 'user (n.)[C]使用者', 'useful (a.)有用的=practical=helpful']
# ['usual (a.)平常的', 'usually (adv.)通常地']
# ['vacation (n.)[U][C]假期']
# ['valley (n.)[C]山谷']
# ['value (n.)[U]價值；重要性', '(vt.)評價；珍重；重視', 'valuable (a.)值錢的；有價值的', 'valueless (a.)無價值的', 'invaluable (a.)無價的；非常貴重的']
# ['victor (n.)[C]優勝者', 'victory (n.)[C][U]勝利；成功', 'victorious (a.)獲勝的']
# ['video (n.)[U][C]錄影機', 'videotape (n.)[C]錄影帶']
# ['village (n.)[C]村莊']
# ['violin (n.)[C]小提琴', 'violinist (n.)[C]小提琴手']
# ['visit (vt.)(vi.)參觀；拜訪=call on', 'visitor (n.)[C]訪客；參觀者']
# ['vocabulary (n.)[C][U]字彙']
# ['volleyball (n.)[C]排球']
# ['vote (vi.)(vt.)投票', '(n.)投票權', 'voter (n.)[C]投票者']
# ['waist (n.)[C]腰', 'waistcoat (n.)[C]背心；馬甲']
# ['wait (vi.)等待；耽擱；服侍', 'waiter (n.)[C]男侍者', 'waitress (n.)[C]女侍者']
# ['wake (vi.)醒來；覺醒(wake-woke-woke)', 'awake (vt.)(vi.)喚醒；覺醒；激起(awake-awoke-awoken)', '(a.)清醒的；意識到的；警惕的']
# ['wallet (n.)[C]皮夾；旅行袋']
# ['water (n.)[U]水；水域', '(vt.)澆灌；以水稀釋=sprinkle', 'waterfall (n.)[C]瀑布', 'waterproof (a.)防水的', 'watermelon (n.)[C]西瓜']
# ['wave (n.)[C]波浪；高漲', '(vt.)(vi.)揮手；搖動']
# ['weapon (n.)[C]武器；兇器']
# ['week (n.)[C]星期', 'weekday (n.)[C]平日', 'weekend (n.)[C]週末', 'weekly (adv.)每週地', '(n.)[C]周刊']
# ['west (n.)西方', '(a.)西方的', '(adv.)西方地', 'western (a.)西方的']
# ['wet (a.)濕的', '(vt.)弄濕(wet-wet/wetted-wet/wetted)']
# ['whale (n.)[C]鯨魚']
# ['wheel (n.)[C]輪子', '(vt.)轉動', 'wheelchair (n.)[C]輪椅']
# ['when (adv.)何時；當…時', '(conj.)當…時', 'whenever (adv.)無論何時；每當']
# ['whisper (vi.)低語；背後議論；颯颯響', '(vt.)低聲說出；背後議論', '(n.)耳語；傳聞；颯颯聲']
# ['wide (a.)寬闊的；廣闊的；廣泛的', '(adv.)廣闊地；寬廣地', 'widen (vt.)放寬；擴大', '(vi.)變寬；變大', 'width (n.)[C][U]寬度；寬闊', 'widespread (a.)普遍的；廣泛的']
# ['wild (a.)野生的；荒涼的；粗暴的', '(adv.)粗暴地；隨便地', 'wildness (n.)[U]荒涼；野生；狂暴', 'wildlife (n.)野生生物']
# ['will (vt.)用意志力促成；遺贈', '(n.)意志=determination', 'willing (a.)願意的；自願的']
# ['wind (vi.)纏繞；轉動；迂迴', '(vt.)轉動；繞；纏繞(wind-wound-wound)', '(n.)[C]轉動；彎曲', '(n.)[C][U]風；氣息', '(vt.)使喘氣；嗅出', 'window (n.)[C]窗戶', 'windshield (n.)[C]擋風玻璃', 'windy (a.)颳大風的']
# ['win (vt.)贏；搏得支持=triumph↔lose(win-won-won)', '(n.)[C]勝利=victory', 'winner (n.)[C]獲勝者']
# ['wire (n.)[C][U]金屬線；電話線；電報', '(vt.)裝配電線；拍電報', 'wireless (a.)無線電的']
# ['wing (n.)[C]翅膀；黨派', '(vi.)飛行']
# ['wisdom (n.)[C][U]智慧；學問', 'wise (a.)聰明的；才智的']
# ['within (prep.)在…內；在…範圍內', '(adv.)在裡面；在心中']
# ['without (prep.)無；在外部', '(adv.)在外表；沒有缺少的情況下']
# ['wolf (n.)[C]狼；色狼；凶惡的人']
# ['wonder (vi.)納悶；想知道；對…感到奇怪', '(n.)[U]驚異，[C]奇觀', 'wonderful (a.)驚奇的；神妙的']
# ['wood (n.)[U]木材', '(n.)[C]森林；樹林', 'wooden (a.)木製的；呆板的', 'woodpecker (n.)[C]啄木鳥']
# ['wool (n.)[U]羊毛；毛線', 'woolen (a.)羊毛製的；羊毛的', '(n.)毛織品']
# ['worth (prep.)…的價值', '(n.)[U]價值', 'worthless (a.)沒有價值的；無用的', 'worthwhile (a.)值得花力氣或時間的', 'worthy (a.)值得的']
# ['wound (n.)[C]創傷；傷口', '(vt.)使受傷', 'wounded (a.)負傷的；受傷害的']
# ['yard (n.)[C]院子；後院']
# ['young (a.)年輕的；新鮮的；缺乏經驗的', '(n.)青年們', 'youngster (n.)[C]小孩；年輕人；幼小動物', 'youth (n.)[U]青少年時期', '(n.)[C]青年；小伙子']
# ['zebra (n.)[C]斑馬']
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %%
# str.find() / -1
def searchForWordInGroup(word):
    for group in dic:
        for line in group:
            location = line.find(word)
            if location == 0 and line[len(word)] == ' ':
                return group
    return None

# %%
def getVoc(line):
    return line.split(' ')[0]
    
def getPartsOfSpeech(line):
    string = line
    returnStr = ''
    while True:
        found = -1
        for part in partsOfSpeech:
            found = string.find(part)
            if found is not -1:
                break
        if found is not -1:
            if found is not 0:
                string = string[found:]
            returnStr += string.split(')')[0] + ')'
            string = string[(len(string.split(')')[0]) + 1):]
        else:
            break
            
    return returnStr
    
def getExplaination(line):
    string = str(line)
    while True:
        found = -1
        for part in partsOfSpeech:
            found = string.find(part)
            if found is not -1:
                break
        if found is not -1:
            if found is not 0:
                string = string[found:]
            string = string[(len(string.split(')')[0]) + 1):]
        else:
            break
    
    return string

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://tw.dictionary.search.yahoo.com/search;_ylt=AwrtXWrsmTNfJ2AAQj17rolQ?p='

def is_all_chinese(strs):
    for _char in strs:
        if not '\u4e00' <= _char <= '\u9fa5':
            return False
    return True

def addParen(line):
    line = '(' + line
    i = 0
    length = len(line)
    parenNum = 1
    while True:
        if (i >= length):
            break
        if line[i] == '.' and parenNum >= 1:
            line = line[0:i + 1] + ')' + line[i + 1:]
            i += 2
            length += 1
            parenNum -= 1
            if line[i].isalpha() and not is_all_chinese(line[i]):
                print(line[i])
                line = line[0:i] + '(' + line[i:]
                parenNum += 1
                i += 1
                length += 1
        else:
            i += 1
    return line

def searchFromYahoo(voc):
       
    resp = requests.get(url + voc)

    resp.encoding = 'utf-8'    #轉換編碼至UTF-8
    
    soup = BeautifulSoup(resp.text, "lxml")
    if soup.find(text = '很抱歉，字典找不到您要的資料喔！') != None:
        return [voc, 'NOT', 'FOUND']
    
    group = []
    
    lines = soup.find(class_="dd cardDesign dictionaryWordCard sys_dict_word_card").contents[1].find(class_="compList mb-25 p-rel").contents[0].contents
    
    for i in range(0, len(lines)):
        line = lines[i]
        if i == 0:
            group.append(voc + ' ' + addParen(line.contents[0].text + line.contents[2].text))
        else:
            group.append(addParen(line.contents[0].text + line.contents[2].text))
    return group
    
    
searchFromYahoo('nonsense')
# Out:
# ['nonsense (n.)[U]胡說；胡鬧，愚蠢的舉動；無價值（或不重要的）的東西', '(int.)胡說！廢話！']

# %%
from docx import Document
from docx.shared import Pt
import time

filePath = 'C:\\Users\\User\\OneDrive\\Documents\\文林心相關\\詳解\\詳解們\\107-2全模(第2回)\\Voc.txt'
wordName = None

def makeVocWord(filePath, wordName = None):
    
    if wordName == None:
        wordName = time.strftime("%Y%m%d_%H%M%S", time.localtime()) + '.docx'
        
    if len(wordName.split('.')) == 1:
        wordName += '.docx'
    elif wordName.split('.')[-1] != 'docx' and wordName.split('.')[-1] != 'doc':
        wordName = wordName[:(len(wordName) - len(wordName.split('.')[-1]) + 1)] + '.docx'

    f = open(filePath, 'r')

    vocList = f.readlines()

    document = Document()

    table = document.add_table(rows = 1, cols = 4)
    table.style = 'TableGrid'

    currentRow = table.rows[0]

    currentRow.cells[0].text = '題號'
    currentRow.cells[1].text = '單字'
    currentRow.cells[2].text = '詞性'
    currentRow.cells[3].text = '解釋'

    table.add_row()
    currentRow = table.rows[-1]
    currentRow.cells[0].text = '1.'

    i = 1

    sectionStartRow = 0
    vocStartRow = 0

    totalNum = 0
    for voc in vocList:
        if voc != '\n':
            totalNum += 1

    currentNum = 0
    for voc in vocList:

        if voc != '\n':
            currentNum += 1
        else:
            i += 1
            currentRow.cells[0].text = str(i) + '.'
            continue

        print('Processing ' + str(currentNum) + '/' + str(totalNum) + ' ' + voc)

        if voc[-1] == '\n':
            group = searchForWordInGroup(voc[:-1])
        else:
            group = searchForWordInGroup(voc)

        if group == None:
            group = searchFromYahoo(voc)

        if 'NOT' in group and 'FOUND' in group:
            currentRow.cells[1].text = group[0]
            currentRow.cells[2].text = group[1]
            currentRow.cells[3].text = group[2]
        else: 
            for string in group:

                if string[0] == '(':
                    currentRow.cells[2].text = getPartsOfSpeech(string)
                    currentRow.cells[3].text = getExplaination(string)
                elif string[0] == '*':
                    currentRow.cells[1].text = string
                elif string[0].isalpha() and not is_all_chinese(string[0]):
                    currentRow.cells[1].text = getVoc(string)
                    currentRow.cells[2].text = getPartsOfSpeech(string)
                    currentRow.cells[3].text = getExplaination(string)
                else:
                    currentRow.cells[3].text = string

                table.add_row()
                currentRow = table.rows[-1]      

    for row in table.rows:
        for cell in row.cells:
            paragraphs = cell.paragraphs
            for paragraph in paragraphs:
                for run in paragraph.runs:
                    font = run.font
                    font.size = Pt(14)
                    font.name = 'Times New Roman'
    f.close()
    document.save(wordName)
    print('Successfully save ' + wordName)
    
makeVocWord(filePath, wordName)
# Out:
# Processing 1/92 arctic
#
# Processing 2/92 worse
#
# Processing 3/92 brand
#
# Processing 4/92 frequent
#
# Processing 5/92 multiply
#
# Processing 6/92 repeat
#
# Processing 7/92 nowadays
#
# Processing 8/92 identical
#
# Processing 9/92 genetic
#
# Processing 10/92 capacity
#
# Processing 11/92 diversity
#
# Processing 12/92 opportunity
#
# Processing 13/92 possibility
#
# Processing 14/92 practically
#
# Processing 15/92 slave
#
# Processing 16/92 define
#
# Processing 17/92 harvest
#
# Processing 18/92 squeeze
#
# Processing 19/92 weave
#
# Processing 20/92 opportunity
#
# Processing 21/92 distribute
#
# Processing 22/92 needy
#
# Processing 23/92 barely
#
# Processing 24/92 fairly
#
# Processing 25/92 merely
#
# Processing 26/92 nearly
#
# Processing 27/92 struggle
#
# Processing 28/92 suffer
#
# Processing 29/92 behave
#
# Processing 30/92 deposit
#
# Processing 31/92 pursue
#
# Processing 32/92 release
#
# Processing 33/92 retire
#
# Processing 34/92 volunteer
#
# Processing 35/92 jealous
#
# Processing 36/92 meaningful
#
# Processing 37/92 primary
#
# Processing 38/92 sufficient
#
# Processing 39/92 office
#
# Processing 40/92 associate
#
# Processing 41/92 locate
#
# Processing 42/92 measure
#
# Processing 43/92 nickname
#
# Processing 44/92 overpass
#
# Processing 45/92 sense
#
# Processing 46/92 keen
#
# Processing 47/92 considerable
#
# Processing 48/92 considerate
#
# Processing 49/92 sensible
#
# Processing 50/92 sensitive
#
# Processing 51/92 addict
#
# Processing 52/92 interact
#
# Processing 53/92 virtual
#
# Processing 54/92 face-to-face
#
# Processing 55/92 drastically
#
# Processing 56/92 fanatically
#
# Processing 57/92 properly
#
# Processing 58/92 remotely
#
# Processing 59/92 explorer
#
# Processing 60/92 lay
#
# Processing 61/92 scenery
#
# Processing 62/92 annoy
#
# Processing 63/92 disgust
#
# Processing 64/92 frustrate
#
# Processing 65/92 impress
#
# Processing 66/92 widen
#
# Processing 67/92 gap
#
# Processing 68/92 guide
#
# Processing 69/92 principal
#
# Processing 70/92 principle
#
# Processing 71/92 skyscraper
#
# Processing 72/92 landmark
#
# Processing 73/92 floor
#
# Processing 74/92 ground
#
# Processing 75/92 fable
#
# Processing 76/92 story
#
# Processing 77/92 conduct
#
# Processing 78/92 overuse
#
# Processing 79/92 opium
#
# Processing 80/92 familiar
#
# Processing 81/92 similar
#
# Processing 82/92 dizzy
#
# Processing 83/92 drowsy
#
# Processing 84/92 income
#
# Processing 85/92 consumption
#
# Processing 86/92 recycle
#
# Processing 87/92 overemphasize
#
# Processing 88/92 confuse
#
# Processing 89/92 refuse
#
# Processing 90/92 produce
#
# Processing 91/92 reduce
#
# Processing 92/92 testWord
# Successfully save 20200813_034351.docx
